# %% [markdown]
# ### Importy

# %%
pip install shap timeshap ta optuna
# Out:
# Collecting shap
#   Downloading shap-0.44.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (533 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 4.6 MB/s eta 0:00:00
# Collecting timeshap
#   Downloading timeshap-1.0.4-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 8.7 MB/s eta 0:00:00
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from timeshap) (0.12.2)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from timeshap) (3.7.1)
# Requirement already satisfied: plotly>=4.6 in /usr/local/lib/python3.10/dist-packages (from timeshap) (5.15.0)
# Requirement already satisfied: altair in /usr/local/lib/python3.10/dist-packages (from timeshap) (4.2.2)
# Collecting feedzai-altair-theme (from timeshap)
#   Downloading feedzai_altair_theme-1.1.3-py3-none-any.whl (12 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 29.2 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.6->timeshap) (8.2.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (0.12.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (0.15.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->timeshap) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair->timeshap) (2.1.3)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29413 sha256=a085a06ad8dc503757c644c2be5f0f506fe36407d9d1a8ad984e01f768099db7
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: slicer, Mako, colorlog, alembic, ta, shap, optuna, feedzai-altair-theme, timeshap
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 feedzai-altair-theme-1.1.3 optuna-3.5.0 shap-0.44.0 slicer-0.0.7 ta-0.11.0 timeshap-1.0.4

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, InputLayer
from keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, InputLayer, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import f1_score, auc
import tensorflow as tf
from tensorflow.keras import backend as K
import itertools
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import shap
from scripts.train_utilities import *
from scripts.essentials import *
from scripts.plots import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, InputLayer
from tensorflow.keras.optimizers import Adam
from keras.models import load_model

# %%
#tf.compat.v1.disable_v2_behavior()

# %%
train_set = pd.read_csv('train_set_full.csv')
test_set = pd.read_csv('test_set_full.csv')
val_set = pd.read_csv('val_set_full.csv')

# %%
prefix = "BA"

# %% [markdown]
# ### Funkcje

# %%
def train_model_from_params(params, X, y, X_val, y_val):
  # Create the model
  model = Sequential()

  # Add Conv1D layer if use_conv is True
  if params['use_conv']:
      model.add(Conv1D(filters=params['conv_filters'],
                      kernel_size=params['conv_kernel_size'],
                      activation='relu',
                      input_shape=(X.shape[1], X.shape[2])))
      model.add(MaxPooling1D(pool_size=2))

  # Add LSTM layers
  for i in range(params['n_layers']):
      model.add(LSTM(units=params[f'lstm_units_{i}'],
                    return_sequences=(i < params['n_layers'] - 1)))

  # Add Dense layer and output layer
  model.add(Dense(units=params['dense_units'], activation='relu'))
  model.add(Dense(units=1))

  # Compile the model
  model.compile(optimizer=Adam(learning_rate=params['learning_rate']), loss='mean_squared_error',metrics=[CustomAUCMetric()])

  # Train the model
  early_stopping = EarlyStopping(monitor='val_custom_auc', patience=40, mode='max', restore_best_weights=True)

  history = model.fit(X, y, epochs=350, validation_data=(X_val, y_val),
                          callbacks=[early_stopping])

  return model

class CustomAUCMetric(tf.keras.metrics.Metric):
    def __init__(self, name="custom_auc", **kwargs):
        super(CustomAUCMetric, self).__init__(name=name, **kwargs)
        self.auc = tf.keras.metrics.AUC(from_logits=True)

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_binary = K.cast(K.greater(y_true, 0), 'float32')
        y_pred_binary = K.cast(K.greater(y_pred, 0), 'float32')
        self.auc.update_state(y_true_binary, y_pred_binary, sample_weight)

    def result(self):
        return self.auc.result()

    def reset_state(self):
        self.auc.reset_states()

def c_f1_score(y_true, y_pred):
    csm = count_signs_matrix(y_true, y_pred)
    #print(csm)
    return (3*csm[1][1]/(csm[1][0]+csm[1][1]+0.001) + 2*csm[1][1]/(csm[0][1]+csm[1][1]+0.001))/5

def custom_f1_metric(y_true, y_pred):
    # Convert y_pred to the same type as y_true
    y_pred = K.cast(y_pred, y_true.dtype)

    y_true_sign = K.sign(y_true)
    y_pred_sign = K.sign(y_pred)

    # Calculate F1 score
    # Since F1 score is a metric from sklearn, we use tf.py_function to wrap it
    return tf.py_function(c_f1_score, (y_true_sign, y_pred_sign), tf.double)

def custom_auc_metric(y_true, y_pred):
    # Convert y_pred to the same type as y_true
    y_pred = K.cast(y_pred, y_true.dtype)

    # Transform regression outputs to 0 and 1 based on sign
    y_true_sign = K.sign(y_true)
    y_pred_sign = K.sign(y_pred)

    # Use TensorFlow's AUC metric
    return tf.py_function(auc, (y_true_sign, y_pred_sign), tf.double)


def create_model(trial, input_shape):
    model = Sequential()
    model.add(InputLayer(input_shape=input_shape))

    # Optionally add a convolutional layer before LSTM
    if trial.suggest_categorical('use_conv', [True, False]):
        model.add(Conv1D(filters=trial.suggest_categorical('conv_filters', [32, 64, 128]),
                         kernel_size=trial.suggest_int('conv_kernel_size', 2, 5),
                         activation='relu',
                         strides=1,
                      padding='causal'))
        model.add(MaxPooling1D(pool_size=2))

    # Optuna can suggest the number of LSTM layers and units
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        model.add(LSTM(units=trial.suggest_categorical(f'lstm_units_{i}', [16, 32, 64]),
                       return_sequences=(i < n_layers - 1)))

    model.add(Dense(units=trial.suggest_categorical('dense_units', [8, 16, 32]), activation='relu'))
    model.add(Dense(units=1))

    # Compile model
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error',metrics=[CustomAUCMetric()])

    return model

def objective(trial):
    model = create_model(trial, input_shape=(X.shape[1], X.shape[2]))

    early_stopping = EarlyStopping(monitor='val_custom_auc', patience=35, mode='max', restore_best_weights=True)

    history = model.fit(X, y, epochs=200, validation_data=(X_val, y_val),
                        callbacks=[early_stopping], verbose=0)

    # Evaluate the model
    val_loss, val_f1 = model.evaluate(X_val, y_val, verbose=0)
    return val_f1

def get_x_y(train_set,
            val_set,
            test_set,
            cols_used,
            target_cols= ['target_5'],
            window_size=10,
            shift_=5):

  X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
  X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
  X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

  y_test = y_test[:-shift_]

  y_base_val = val_set[target_cols[0]].shift(shift_)[window_size:].values
  y_base_test = test_set[target_cols[0]].shift(shift_)[window_size:-shift_].values
  y_base_train = train_set[target_cols[0]].shift(shift_)[window_size:].values
  y_base0_val = [0 for i in range((val_set.shape[0]-window_size))]
  y_base0_train = [0 for i in range((train_set.shape[0]-window_size))]
  y_base0_test = [0 for i in range(len(y_test))]

  return X,y,X_val,y_val,X_test,y_test,y_base_train,y_base_val,y_base_test,y_base0_train,y_base0_val,y_base0_test

# %%
def create_unique_subsets(columns, subset_size=5, min_diff=2):
    """
    Create subsets of columns where each subset differs from every other subset by at least 'min_diff' columns.

    :param columns: List of all columns.
    :param subset_size: The size of each subset.
    :param min_diff: Minimum number of different columns between any two subsets.
    :return: A list of unique subsets.
    """
    all_combinations = list(itertools.combinations(columns, subset_size))
    unique_subsets = []

    for combo in all_combinations:
        if all(len(set(combo) - set(subset)) >= min_diff for subset in unique_subsets):
            unique_subsets.append(combo)

    return unique_subsets

def make_model_better(X, y, X_val, y_val, n_epochs, lstm_units=64, dense_units=10, patience=5):
    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping and model checkpoint
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val), callbacks=[early_stopping, model_checkpoint])

    return model, history

# Example usage:
# model, history = make_model(X_train, y_train, X_val, y_val, n_epochs=50, lstm_units=64, dense_units=10, patience=5)

def window_dataset(df, target_column, window_size):
    X = []
    y = []

    # Iterate over the dataset
    for i in range(len(df) - window_size):
        # Extract the window of data
        window = df[i:i+window_size]

        # Extract the features (X) and target (y)
        X.append(window.drop(columns=[target_column]).values)
        y.append(df[target_column][i+window_size])

    return np.array(X), np.array(y)

def run_multiple_models(train_set,val_set,cols_subset,n_epochs=100):

  window_size = 14
  target_cols = ['target_7']
  mse_val = []
  mse_train = []
  aggregated_shap = []
  for idx,cols_used in enumerate(cols_subset):
    print('-------------------------------')
    print(idx)

    X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
    X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)

    model,history = make_model(X,y, X_val, y_val, n_epochs)

    mse_val.append(min(history.history['val_loss']))
    mse_train.append(min(history.history['loss']))

    explainer = shap.DeepExplainer(model, X)
    shap_values = explainer.shap_values(X_val)

    aggregated_shap.append(np.mean(np.abs(shap_values[0]), axis=0))

    #create df
    if (idx%15 == 0):
      df = pd.DataFrame({'cols_used': cols_subset[:idx+1], 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
      df.to_csv('df_shap'+str(idx)+'.csv')
  df = pd.DataFrame({'cols_used': cols_subset, 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
  df.to_csv('df_shap_final.csv')

  return df

def parse_cols_used(cols_string):
    """
    Parses the column names used in the model from the string representation.

    Args:
    cols_string (str): A string representing the tuple of column names.

    Returns:
    list: A list of column names.
    """
    # Remove the outer brackets and split the string into column names
    cols = cols_string.strip("()").split(", ")
    # Remove quotes and extra characters from column names
    cleaned_cols = [col.strip("'") for col in cols]
    return cleaned_cols

def parse_shap_values(shap_string):
    """
    Parses a string representation of a list of lists of SHAP values into a Python list of lists.

    Args:
    shap_string (str): A string representing a list of lists of SHAP values.

    Returns:
    list of lists: A list of lists of SHAP values.
    """
    # Remove the outer brackets and split the string into rows, handling newline characters
    rows = shap_string.strip('[]').split('\n')

    # Parse each row into a list of floats
    parsed_rows = [list(map(float, row.strip(' []').split())) for row in rows]

    return parsed_rows

def make_model(X, y, n_epochs, lstm_units=32,dense_units=8):
    tf.keras.backend.clear_session()

    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    history = model.fit(X, y, epochs=n_epochs,
                        verbose=0)

    return model, history

def plot_mean_feature_importance(shap_values, feature_names,max_=False):
    """
    Plot the mean importance of each feature across all time steps.

    :param shap_values: A 3D array of SHAP values with shape (samples, window_size, num_features).
    :param feature_names: List of feature names.
    """
    if max_:
    # Aggregate SHAP values across all samples and time steps
      aggregated_shap = np.max(np.abs(shap_values), axis=(0))
    else:
      aggregated_shap = np.mean(np.abs(shap_values), axis=(0))


    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.bar(feature_names, aggregated_shap)
    plt.title('Mean Feature Importance Across All Time Steps')
    plt.ylabel('Mean SHAP Value')
    plt.xlabel('Features')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Optuna

# %%
import random

random.seed(10)
np.random.seed(10)

# Set seed for TensorFlow
tf.random.set_seed(10)

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
'norm_rsi_14', 'norm_slowk_14', 'minmax_daily_variation', 'minmax_BA_Volume'
]

X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

study_f = optuna.create_study(direction='maximize')
study_f.optimize(objective, n_trials=15)  # Adjust n_trials to how many trials you want to run

print(study_f.best_params)
# Out:
# [I 2023-12-29 15:19:20,806] A new study created in memory with name: no-name-58873139-6724-42cf-9947-e8b70b798e74
# [I 2023-12-29 15:19:47,788] Trial 0 finished with value: 0.6022727489471436 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 16, 'lstm_units_2': 16, 'dense_units': 16, 'learning_rate': 6.0924520649218124e-05}. Best is trial 0 with value: 0.6022727489471436.
# [I 2023-12-29 15:20:05,028] Trial 1 finished with value: 0.5681818127632141 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 0.00840255947722783}. Best is trial 0 with value: 0.6022727489471436.
# [I 2023-12-29 15:20:30,248] Trial 2 finished with value: 0.6136363744735718 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 32, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 0.003169988819411461}. Best is trial 2 with value: 0.6136363744735718.
# [I 2023-12-29 15:20:40,335] Trial 3 finished with value: 0.5 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 5, 'n_layers': 1, 'lstm_units_0': 16, 'dense_units': 32, 'learning_rate': 2.0061625107652016e-05}. Best is trial 2 with value: 0.6136363744735718.
# [I 2023-12-29 15:21:07,744] Trial 4 finished with value: 0.6363636255264282 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 32, 'lstm_units_2': 64, 'dense_units': 32, 'learning_rate': 0.0014816564580597705}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:21:35,171] Trial 5 finished with value: 0.5340908765792847 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 64, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 2.843073068991549e-05}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:21:48,891] Trial 6 finished with value: 0.5397726893424988 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 32, 'learning_rate': 0.00032591926208843324}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:22:14,170] Trial 7 finished with value: 0.6022727489471436 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 32, 'learning_rate': 0.001876438519410773}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:22:41,697] Trial 8 finished with value: 0.5965908765792847 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 64, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 1.4058489196919413e-05}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:22:56,962] Trial 9 finished with value: 0.6136363744735718 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 2, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 32, 'dense_units': 16, 'learning_rate': 0.0005837285529106433}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:23:27,500] Trial 10 finished with value: 0.6193181872367859 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 32, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.0001188487826522767}. Best is trial 4 with value: 0.6363636255264282.
# [I 2023-12-29 15:23:54,382] Trial 11 finished with value: 0.6647727489471436 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 32, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.00013161039452650483}. Best is trial 11 with value: 0.6647727489471436.
# [I 2023-12-29 15:24:14,749] Trial 12 finished with value: 0.5 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 32, 'lstm_units_2': 32, 'dense_units': 8, 'learning_rate': 0.0009058685047780155}. Best is trial 11 with value: 0.6647727489471436.
# [I 2023-12-29 15:24:29,907] Trial 13 finished with value: 0.5625 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 32, 'dense_units': 8, 'learning_rate': 0.00012702568532404956}. Best is trial 11 with value: 0.6647727489471436.
# [I 2023-12-29 15:24:56,379] Trial 14 finished with value: 0.6818181872367859 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.0001914571101929177}. Best is trial 14 with value: 0.6818181872367859.
# {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.0001914571101929177}

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
'mean_influential', 'mean_trustworthy', 'finbert_Score', 'bart_Score'
              ]

X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

study_n = optuna.create_study(direction='maximize')
study_n.optimize(objective, n_trials=15)  # Adjust n_trials to how many trials you want to run

print(study_n.best_params)
# Out:
# [I 2023-12-29 15:29:23,575] A new study created in memory with name: no-name-0ba0d8f8-d75d-426e-acaf-932962e4287c
# [I 2023-12-29 15:29:50,837] Trial 0 finished with value: 0.5 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 16, 'dense_units': 8, 'learning_rate': 0.004296268373278586}. Best is trial 0 with value: 0.5.
# [I 2023-12-29 15:30:11,881] Trial 1 finished with value: 0.6079545617103577 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 4, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 32, 'dense_units': 16, 'learning_rate': 0.0067176383099900846}. Best is trial 1 with value: 0.6079545617103577.
# [I 2023-12-29 15:30:31,043] Trial 2 finished with value: 0.6931818127632141 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 2, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 64, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 0.001072085522286904}. Best is trial 2 with value: 0.6931818127632141.
# [I 2023-12-29 15:30:40,387] Trial 3 finished with value: 0.6988636255264282 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 32, 'learning_rate': 9.992820250723423e-05}. Best is trial 3 with value: 0.6988636255264282.
# [I 2023-12-29 15:30:53,341] Trial 4 finished with value: 0.8181818127632141 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 1, 'lstm_units_0': 16, 'dense_units': 8, 'learning_rate': 3.165513979270335e-05}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:31:18,068] Trial 5 finished with value: 0.6306818127632141 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 2.7074522574950247e-05}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:31:30,772] Trial 6 finished with value: 0.48295456171035767 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 16, 'dense_units': 16, 'learning_rate': 3.5320018532731875e-05}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:32:16,178] Trial 7 finished with value: 0.5511363744735718 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 4, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 0.004681219035678669}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:32:26,940] Trial 8 finished with value: 0.5965908765792847 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 8, 'learning_rate': 1.168750710902339e-05}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:32:41,460] Trial 9 finished with value: 0.7159091234207153 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 2, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 0.00010844453445762782}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:32:55,411] Trial 10 finished with value: 0.7102272510528564 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 8, 'learning_rate': 0.0005406440526794025}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:33:09,124] Trial 11 finished with value: 0.5227272510528564 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 2, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 32, 'dense_units': 8, 'learning_rate': 0.00013624859845703051}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:33:31,520] Trial 12 finished with value: 0.6022727489471436 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 16, 'learning_rate': 0.00010605916952206705}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:33:45,761] Trial 13 finished with value: 0.5795454978942871 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 8, 'learning_rate': 3.5499718197387304e-05}. Best is trial 4 with value: 0.8181818127632141.
# [I 2023-12-29 15:34:11,187] Trial 14 finished with value: 0.625 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 5, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 64, 'dense_units': 32, 'learning_rate': 0.0002525623414100186}. Best is trial 4 with value: 0.8181818127632141.
# {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 1, 'lstm_units_0': 16, 'dense_units': 8, 'learning_rate': 3.165513979270335e-05}

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
'norm_rsi_14', 'norm_slowk_14', 'minmax_daily_variation', 'minmax_BA_Volume',
'mean_influential', 'mean_trustworthy', 'finbert_Score', 'bart_Score'
             ]

X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

study_full = optuna.create_study(direction='maximize')
study_full.optimize(objective, n_trials=15)  # Adjust n_trials to how many trials you want to run

print(study_full.best_params)
# Out:
# [I 2023-12-29 15:35:55,709] A new study created in memory with name: no-name-af4c209a-524b-4089-92a5-28f0ba03b55b
# [I 2023-12-29 15:36:20,383] Trial 0 finished with value: 0.6136363744735718 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 5, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 8, 'learning_rate': 0.00023168006508671507}. Best is trial 0 with value: 0.6136363744735718.
# [I 2023-12-29 15:36:43,678] Trial 1 finished with value: 0.7159091234207153 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 3, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 16, 'learning_rate': 0.00034565802059327556}. Best is trial 1 with value: 0.7159091234207153.
# [I 2023-12-29 15:37:08,480] Trial 2 finished with value: 0.6647727489471436 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 0.004095200438951294}. Best is trial 1 with value: 0.7159091234207153.
# [I 2023-12-29 15:37:55,303] Trial 3 finished with value: 0.6590909361839294 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 32, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.0002457498733503463}. Best is trial 1 with value: 0.7159091234207153.
# [I 2023-12-29 15:38:43,069] Trial 4 finished with value: 0.8465908765792847 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 64, 'lstm_units_2': 16, 'dense_units': 8, 'learning_rate': 0.00841049837469833}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:38:53,285] Trial 5 finished with value: 0.6136363744735718 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 5, 'n_layers': 1, 'lstm_units_0': 16, 'dense_units': 16, 'learning_rate': 0.0036279199002940245}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:39:17,860] Trial 6 finished with value: 0.7272726893424988 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 16, 'dense_units': 16, 'learning_rate': 0.00044152269223598356}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:39:40,798] Trial 7 finished with value: 0.7215909361839294 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 16, 'learning_rate': 0.0009726568116706351}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:39:55,539] Trial 8 finished with value: 0.6875 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 5, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 64, 'dense_units': 8, 'learning_rate': 0.00023453887840995088}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:40:10,493] Trial 9 finished with value: 0.6931818127632141 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 16, 'dense_units': 8, 'learning_rate': 0.0007663470708319406}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:40:31,523] Trial 10 finished with value: 0.6875 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 64, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 2.4062383306708067e-05}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:40:58,259] Trial 11 finished with value: 0.7272727489471436 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 2.8423281908680023e-05}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:41:20,975] Trial 12 finished with value: 0.5681818127632141 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 1.0111983692776981e-05}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:41:48,244] Trial 13 finished with value: 0.6363636255264282 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 4.515455973131131e-05}. Best is trial 4 with value: 0.8465908765792847.
# [I 2023-12-29 15:42:12,321] Trial 14 finished with value: 0.75 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 32, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 7.077078360603146e-05}. Best is trial 4 with value: 0.8465908765792847.
# {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 64, 'lstm_units_2': 16, 'dense_units': 8, 'learning_rate': 0.00841049837469833}

# %% [markdown]
# ### Model Finance

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
'norm_rsi_14', 'norm_slowk_14', 'minmax_daily_variation', 'minmax_BA_Volume'
             ]
shift_ = 5

X, y, X_val, y_val, X_test, y_test, y_base_train, y_base_val, y_base_test,\
y_base0_train, y_base0_val, y_base0_test = get_x_y(train_set = train_set,
        val_set = val_set, test_set = test_set, cols_used = cols_used,
        target_cols= target_cols, window_size=10, shift_= shift_)

# %%
model = train_model_from_params(study_f.best_params, X, y, X_val, y_val)
# Out:
# Epoch 1/350
# 21/21 [==============================] - 7s 91ms/step - loss: 0.0029 - custom_auc: 0.5078 - val_loss: 0.0014 - val_custom_auc: 0.4318
# Epoch 2/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0029 - custom_auc: 0.5098 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 3/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0029 - custom_auc: 0.5089 - val_loss: 0.0014 - val_custom_auc: 0.6136
# Epoch 4/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0029 - custom_auc: 0.4784 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 5/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0029 - custom_auc: 0.4935 - val_loss: 0.0014 - val_custom_auc: 0.5398
# Epoch 6/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0028 - custom_auc: 0.5107 - val_loss: 0.0014 - val_custom_auc: 0.2898
# Epoch 7/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0028 - custom_auc: 0.5053 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 8/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0028 - custom_auc: 0.5183 - val_loss: 0.0014 - val_custom_auc: 0.6023
# Epoch 9/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0028 - custom_auc: 0.5278 - val_loss: 0.0014 - val_custom_auc: 0.4773
# Epoch 10/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0028 - custom_auc: 0.5324 - val_loss: 0.0014 - val_custom_auc: 0.4773
# Epoch 11/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0028 - custom_auc: 0.5189 - val_loss: 0.0014 - val_custom_auc: 0.4148
# Epoch 12/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5341 - val_loss: 0.0014 - val_custom_auc: 0.3523
# Epoch 13/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5270 - val_loss: 0.0014 - val_custom_auc: 0.3182
# Epoch 14/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5477 - val_loss: 0.0014 - val_custom_auc: 0.2727
# Epoch 15/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0028 - custom_auc: 0.5451 - val_loss: 0.0014 - val_custom_auc: 0.3125
# Epoch 16/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5504 - val_loss: 0.0014 - val_custom_auc: 0.2727
# Epoch 17/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5665 - val_loss: 0.0014 - val_custom_auc: 0.4545
# Epoch 18/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5656 - val_loss: 0.0014 - val_custom_auc: 0.3352
# Epoch 19/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5596 - val_loss: 0.0014 - val_custom_auc: 0.4773
# Epoch 20/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5562 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 21/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5486 - val_loss: 0.0015 - val_custom_auc: 0.3750
# Epoch 22/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5563 - val_loss: 0.0014 - val_custom_auc: 0.5000
# Epoch 23/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5644 - val_loss: 0.0014 - val_custom_auc: 0.5000
# Epoch 24/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5664 - val_loss: 0.0015 - val_custom_auc: 0.3864
# Epoch 25/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5637 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 26/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5803 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 27/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0026 - custom_auc: 0.5774 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 28/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5605 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 29/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0026 - custom_auc: 0.5764 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 30/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0026 - custom_auc: 0.5777 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 31/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0026 - custom_auc: 0.5908 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 32/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0026 - custom_auc: 0.5795 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 33/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0026 - custom_auc: 0.5862 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 34/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0026 - custom_auc: 0.5799 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 35/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0026 - custom_auc: 0.5772 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 36/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0026 - custom_auc: 0.5888 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 37/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0026 - custom_auc: 0.5886 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 38/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.5860 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 39/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0025 - custom_auc: 0.5844 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 40/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0025 - custom_auc: 0.5799 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 41/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0026 - custom_auc: 0.5873 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 42/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0026 - custom_auc: 0.5978 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 43/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.5931 - val_loss: 0.0016 - val_custom_auc: 0.4545
# Epoch 44/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.6057 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 45/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.6050 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 46/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.5967 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 47/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.6045 - val_loss: 0.0016 - val_custom_auc: 0.3352

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 21/21 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step

# %%
print(roc_auc_score(y>0, y_pred_train.flatten()>0))
print(roc_auc_score(y_val>0, y_pred_val.flatten()>0))
print(roc_auc_score(y_test>0, y_pred_test[:-shift_].flatten()>0))
# Out:
# 0.5235352981362276
# 0.6818181818181819
# 0.6339285714285714

# %%
print(f'train')
print(count_signs_matrix(y, y_pred_train.flatten()))
print(f'val')
print(count_signs_matrix(y_val, y_pred_val.flatten()))
print(f'test')
print(count_signs_matrix(y_test, y_pred_test[:-shift_].flatten()))
# Out:
# train
# [[255  88]
#  [211  92]]
# val
# [[ 8  0]
#  [14  8]]
# test
# [[11 13]
#  [ 4 17]]

# %%
k=-90
m = 8
plot_actual_vs_predicted(y[k:], y_pred_train[k:]*m, y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val*m, y_base0_val)

# %%
plot_actual_vs_predicted(y_test, y_pred_test*m, y_base0_test)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, y_test, y_pred_test[:-shift_], y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, y_test, y_base0_test, y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, y_test, y_base_test, y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.039429  0.002832  0.053217  0.007212  106.449598  1.513117
# Test        0.038670  0.001962  0.044299 -0.012658   99.984074  1.483999
# Validation  0.028075  0.001454  0.038126 -0.043611  249.714058  1.077404
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.039650  0.002853  0.053411 -0.000031  100.0  1.521588
# Test        0.039241  0.002021  0.044954 -0.042823  100.0  1.505902
# Validation  0.027415  0.001435  0.037876 -0.029927  100.0  1.052056
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score         MAPE      MASE
# Train       0.058321  0.005983  0.077351 -1.097411   552.156845  2.238101
# Test        0.036883  0.002296  0.047921 -0.185065   194.894003  1.415398
# Validation  0.052187  0.004144  0.064371 -1.974836  4423.503320  2.002708

# %%
#save model to h5
model.save(prefix+'_lstm_fin_cols.h5')

# %% [markdown]
# ### Model News

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
            'vader_Score', 'bart_Score', 'mean_influential', 'finbert_Score', 'mean_trustworthy'
             ]
shift_ = 5

X, y, X_val, y_val, X_test, y_test, y_base_train, y_base_val, y_base_test,\
y_base0_train, y_base0_val, y_base0_test = get_x_y(train_set = train_set,
        val_set = val_set, test_set = test_set, cols_used = cols_used,
        target_cols= target_cols, window_size=10, shift_= shift_)

# %%
model = train_model_from_params(study_n.best_params, X, y, X_val, y_val)
# Out:
# Epoch 1/350
# 21/21 [==============================] - 3s 36ms/step - loss: 0.0045 - custom_auc: 0.5205 - val_loss: 0.0016 - val_custom_auc: 0.5398
# Epoch 2/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0035 - custom_auc: 0.5284 - val_loss: 0.0013 - val_custom_auc: 0.5455
# Epoch 3/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0032 - custom_auc: 0.5023 - val_loss: 0.0014 - val_custom_auc: 0.5795
# Epoch 4/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0032 - custom_auc: 0.5101 - val_loss: 0.0013 - val_custom_auc: 0.5795
# Epoch 5/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0032 - custom_auc: 0.5153 - val_loss: 0.0013 - val_custom_auc: 0.5170
# Epoch 6/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0031 - custom_auc: 0.5150 - val_loss: 0.0013 - val_custom_auc: 0.5170
# Epoch 7/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0031 - custom_auc: 0.5213 - val_loss: 0.0013 - val_custom_auc: 0.5795
# Epoch 8/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0030 - custom_auc: 0.5349 - val_loss: 0.0014 - val_custom_auc: 0.5795
# Epoch 9/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0030 - custom_auc: 0.5337 - val_loss: 0.0014 - val_custom_auc: 0.5795
# Epoch 10/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0030 - custom_auc: 0.5178 - val_loss: 0.0014 - val_custom_auc: 0.5795
# Epoch 11/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0030 - custom_auc: 0.5157 - val_loss: 0.0014 - val_custom_auc: 0.6023
# Epoch 12/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0030 - custom_auc: 0.5168 - val_loss: 0.0014 - val_custom_auc: 0.6648
# Epoch 13/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0029 - custom_auc: 0.5110 - val_loss: 0.0015 - val_custom_auc: 0.6420
# Epoch 14/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0029 - custom_auc: 0.5215 - val_loss: 0.0015 - val_custom_auc: 0.6648
# Epoch 15/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0029 - custom_auc: 0.5158 - val_loss: 0.0015 - val_custom_auc: 0.6420
# Epoch 16/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0029 - custom_auc: 0.5296 - val_loss: 0.0015 - val_custom_auc: 0.6420
# Epoch 17/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0029 - custom_auc: 0.5378 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 18/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0029 - custom_auc: 0.5367 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 19/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0029 - custom_auc: 0.5382 - val_loss: 0.0015 - val_custom_auc: 0.6420
# Epoch 20/350
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0029 - custom_auc: 0.5373 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 21/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0029 - custom_auc: 0.5300 - val_loss: 0.0015 - val_custom_auc: 0.6420
# Epoch 22/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0029 - custom_auc: 0.5402 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 23/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5406 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 24/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5393 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 25/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0028 - custom_auc: 0.5478 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 26/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0028 - custom_auc: 0.5453 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 27/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0028 - custom_auc: 0.5502 - val_loss: 0.0015 - val_custom_auc: 0.6420
# Epoch 28/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5473 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 29/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5490 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 30/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5534 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 31/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5533 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 32/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0028 - custom_auc: 0.5561 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 33/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0028 - custom_auc: 0.5592 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 34/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0028 - custom_auc: 0.5639 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 35/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0028 - custom_auc: 0.5608 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 36/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0028 - custom_auc: 0.5654 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 37/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0028 - custom_auc: 0.5632 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 38/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0028 - custom_auc: 0.5705 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 39/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0027 - custom_auc: 0.5623 - val_loss: 0.0015 - val_custom_auc: 0.6193
# Epoch 40/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5736 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 41/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5661 - val_loss: 0.0014 - val_custom_auc: 0.6420
# Epoch 42/350
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0027 - custom_auc: 0.5641 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 43/350
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0027 - custom_auc: 0.5753 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 44/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5789 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 45/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5761 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 46/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5875 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 47/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0027 - custom_auc: 0.5752 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 48/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5793 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 49/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5854 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 50/350
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0027 - custom_auc: 0.5825 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 51/350
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0027 - custom_auc: 0.5851 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 52/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0027 - custom_auc: 0.5911 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 53/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0027 - custom_auc: 0.5854 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 54/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0027 - custom_auc: 0.5831 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 55/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0027 - custom_auc: 0.5857 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 56/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0027 - custom_auc: 0.5870 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 57/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.5897 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 58/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.5964 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 59/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.5934 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 60/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.5967 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 61/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.5947 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 62/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.5952 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 63/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6048 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 64/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.6009 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 65/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6067 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 66/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.6071 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 67/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.6021 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 68/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6045 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 69/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6035 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 70/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6121 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 71/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6077 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 72/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.6262 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 73/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6037 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 74/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6045 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 75/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6207 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 76/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6005 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 77/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6093 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 78/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0026 - custom_auc: 0.6045 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 79/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0026 - custom_auc: 0.6097 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 80/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6221 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 81/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6208 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 82/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6198 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 83/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6230 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 84/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6281 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 85/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6197 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 86/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6170 - val_loss: 0.0014 - val_custom_auc: 0.6591
# Epoch 87/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6210 - val_loss: 0.0014 - val_custom_auc: 0.6591
# Epoch 88/350
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0025 - custom_auc: 0.6198 - val_loss: 0.0015 - val_custom_auc: 0.6818
# Epoch 89/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0025 - custom_auc: 0.6224 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 90/350
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0025 - custom_auc: 0.6269 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 91/350
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0025 - custom_auc: 0.6176 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 92/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6260 - val_loss: 0.0014 - val_custom_auc: 0.6591
# Epoch 93/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6229 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 94/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6272 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 95/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6294 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 96/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6238 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 97/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6262 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 98/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6270 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 99/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6267 - val_loss: 0.0014 - val_custom_auc: 0.7273
# Epoch 100/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6271 - val_loss: 0.0014 - val_custom_auc: 0.6591
# Epoch 101/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0025 - custom_auc: 0.6287 - val_loss: 0.0014 - val_custom_auc: 0.6591
# Epoch 102/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6283 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 103/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0025 - custom_auc: 0.6289 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 104/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0024 - custom_auc: 0.6267 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 105/350
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0024 - custom_auc: 0.6240 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 106/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0024 - custom_auc: 0.6224 - val_loss: 0.0014 - val_custom_auc: 0.6818
# Epoch 107/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0024 - custom_auc: 0.6287 - val_loss: 0.0014 - val_custom_auc: 0.7045
# Epoch 108/350
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0024 - custom_auc: 0.6355 - val_loss: 0.0014 - val_custom_auc: 0.7045

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 432ms/step
# 21/21 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y>0, y_pred_train.flatten()>0))
print(roc_auc_score(y_val>0, y_pred_val.flatten()>0))
print(roc_auc_score(y_test>0, y_pred_test[:-shift_].flatten()>0))
# Out:
# 0.5990243339202723
# 0.7272727272727273
# 0.46726190476190477

# %%
print(f'train')
print(count_signs_matrix(y, y_pred_train.flatten()))
print(f'val')
print(count_signs_matrix(y_val, y_pred_val.flatten()))
print(f'test')
print(count_signs_matrix(y_test, y_pred_test[:-shift_].flatten()))
# Out:
# train
# [[180 163]
#  [ 99 204]]
# val
# [[ 8  0]
#  [12 10]]
# test
# [[11 13]
#  [11 10]]

# %%
k=-90
m = 1
plot_actual_vs_predicted(y[k:], y_pred_train[k:]*m, y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val*m, y_base0_val)

# %%
plot_actual_vs_predicted(y_test, y_pred_test*m, y_base0_test)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, y_test, y_pred_test[:-shift_], y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, y_test, y_base0_test, y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, y_test, y_base_test, y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score         MAPE      MASE
# Train       0.037755  0.002595  0.050942  0.090290   169.727265  1.448876
# Test        0.043359  0.002610  0.051087 -0.346827   120.895657  1.663935
# Validation  0.027973  0.001398  0.037387 -0.003545  1369.387360  1.073488
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.039650  0.002853  0.053411 -0.000031  100.0  1.521588
# Test        0.039241  0.002021  0.044954 -0.042823  100.0  1.505902
# Validation  0.027415  0.001435  0.037876 -0.029927  100.0  1.052056
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score         MAPE      MASE
# Train       0.058321  0.005983  0.077351 -1.097411   552.156845  2.238101
# Test        0.036883  0.002296  0.047921 -0.185065   194.894003  1.415398
# Validation  0.052187  0.004144  0.064371 -1.974836  4423.503320  2.002708

# %%
#save model to h5
model.save(prefix+'_lstm_news_cols.h5')

# %% [markdown]
# ### Model Full

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
            'minmax_low_norm', 'minmax_high_norm', 'norm_rsi_gspc_14', 'norm_slowk_14' ,
            'vader_Score', 'bart_Score', 'mean_influential', 'finbert_Score', 'mean_trustworthy'
             ]
shift_ = 5

X, y, X_val, y_val, X_test, y_test, y_base_train, y_base_val, y_base_test,\
y_base0_train, y_base0_val, y_base0_test = get_x_y(train_set = train_set,
        val_set = val_set, test_set = test_set, cols_used = cols_used,
        target_cols= target_cols, window_size=10, shift_= shift_)

# %%
model = train_model_from_params(study_full.best_params, X, y, X_val, y_val)
# Out:
# Epoch 1/350
# 21/21 [==============================] - 9s 125ms/step - loss: 0.0076 - custom_auc: 0.4930 - val_loss: 0.0016 - val_custom_auc: 0.4773
# Epoch 2/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0031 - custom_auc: 0.5132 - val_loss: 0.0018 - val_custom_auc: 0.5000
# Epoch 3/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0031 - custom_auc: 0.5368 - val_loss: 0.0022 - val_custom_auc: 0.5000
# Epoch 4/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0030 - custom_auc: 0.5178 - val_loss: 0.0017 - val_custom_auc: 0.5000
# Epoch 5/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0029 - custom_auc: 0.5352 - val_loss: 0.0015 - val_custom_auc: 0.5455
# Epoch 6/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0029 - custom_auc: 0.4844 - val_loss: 0.0014 - val_custom_auc: 0.5000
# Epoch 7/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5076 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 8/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5042 - val_loss: 0.0013 - val_custom_auc: 0.5000
# Epoch 9/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5059 - val_loss: 0.0015 - val_custom_auc: 0.5227
# Epoch 10/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5491 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 11/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0028 - custom_auc: 0.4973 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 12/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0029 - custom_auc: 0.5005 - val_loss: 0.0017 - val_custom_auc: 0.5000
# Epoch 13/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5195 - val_loss: 0.0014 - val_custom_auc: 0.6136
# Epoch 14/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5615 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 15/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0029 - custom_auc: 0.4955 - val_loss: 0.0016 - val_custom_auc: 0.5000
# Epoch 16/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5351 - val_loss: 0.0015 - val_custom_auc: 0.5682
# Epoch 17/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5639 - val_loss: 0.0014 - val_custom_auc: 0.6420
# Epoch 18/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5310 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 19/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.5588 - val_loss: 0.0015 - val_custom_auc: 0.5455
# Epoch 20/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5487 - val_loss: 0.0014 - val_custom_auc: 0.4148
# Epoch 21/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5652 - val_loss: 0.0017 - val_custom_auc: 0.5000
# Epoch 22/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5298 - val_loss: 0.0020 - val_custom_auc: 0.5000
# Epoch 23/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0029 - custom_auc: 0.5280 - val_loss: 0.0015 - val_custom_auc: 0.5682
# Epoch 24/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5440 - val_loss: 0.0015 - val_custom_auc: 0.5227
# Epoch 25/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5131 - val_loss: 0.0016 - val_custom_auc: 0.5227
# Epoch 26/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0029 - custom_auc: 0.5082 - val_loss: 0.0014 - val_custom_auc: 0.5341
# Epoch 27/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0029 - custom_auc: 0.5345 - val_loss: 0.0015 - val_custom_auc: 0.5000
# Epoch 28/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0029 - custom_auc: 0.4966 - val_loss: 0.0014 - val_custom_auc: 0.5284
# Epoch 29/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.5393 - val_loss: 0.0014 - val_custom_auc: 0.5568
# Epoch 30/350
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0028 - custom_auc: 0.5282 - val_loss: 0.0017 - val_custom_auc: 0.5000
# Epoch 31/350
# 21/21 [==============================] - 1s 27ms/step - loss: 0.0028 - custom_auc: 0.5395 - val_loss: 0.0014 - val_custom_auc: 0.4205
# Epoch 32/350
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0027 - custom_auc: 0.5630 - val_loss: 0.0014 - val_custom_auc: 0.5170
# Epoch 33/350
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0027 - custom_auc: 0.5542 - val_loss: 0.0016 - val_custom_auc: 0.4375
# Epoch 34/350
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0027 - custom_auc: 0.5784 - val_loss: 0.0020 - val_custom_auc: 0.5000
# Epoch 35/350
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0028 - custom_auc: 0.5192 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 36/350
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0027 - custom_auc: 0.5664 - val_loss: 0.0014 - val_custom_auc: 0.4034
# Epoch 37/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0026 - custom_auc: 0.5673 - val_loss: 0.0013 - val_custom_auc: 0.6364
# Epoch 38/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0026 - custom_auc: 0.5809 - val_loss: 0.0015 - val_custom_auc: 0.4886
# Epoch 39/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0026 - custom_auc: 0.5913 - val_loss: 0.0014 - val_custom_auc: 0.4545
# Epoch 40/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0025 - custom_auc: 0.5931 - val_loss: 0.0018 - val_custom_auc: 0.4034
# Epoch 41/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0025 - custom_auc: 0.5681 - val_loss: 0.0019 - val_custom_auc: 0.3807
# Epoch 42/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0025 - custom_auc: 0.5821 - val_loss: 0.0019 - val_custom_auc: 0.4489
# Epoch 43/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0026 - custom_auc: 0.5623 - val_loss: 0.0015 - val_custom_auc: 0.5057
# Epoch 44/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0025 - custom_auc: 0.5745 - val_loss: 0.0017 - val_custom_auc: 0.5227
# Epoch 45/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0023 - custom_auc: 0.6131 - val_loss: 0.0013 - val_custom_auc: 0.6364
# Epoch 46/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0024 - custom_auc: 0.5939 - val_loss: 0.0016 - val_custom_auc: 0.3807
# Epoch 47/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0025 - custom_auc: 0.5763 - val_loss: 0.0019 - val_custom_auc: 0.5227
# Epoch 48/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0024 - custom_auc: 0.5780 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 49/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0022 - custom_auc: 0.6283 - val_loss: 0.0017 - val_custom_auc: 0.4545
# Epoch 50/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0021 - custom_auc: 0.6321 - val_loss: 0.0015 - val_custom_auc: 0.4545
# Epoch 51/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0020 - custom_auc: 0.6356 - val_loss: 0.0023 - val_custom_auc: 0.4716
# Epoch 52/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0021 - custom_auc: 0.6467 - val_loss: 0.0025 - val_custom_auc: 0.5057
# Epoch 53/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0022 - custom_auc: 0.5956 - val_loss: 0.0021 - val_custom_auc: 0.4489
# Epoch 54/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0019 - custom_auc: 0.6618 - val_loss: 0.0022 - val_custom_auc: 0.3977
# Epoch 55/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0019 - custom_auc: 0.6437 - val_loss: 0.0020 - val_custom_auc: 0.4716
# Epoch 56/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0016 - custom_auc: 0.6955 - val_loss: 0.0026 - val_custom_auc: 0.4489
# Epoch 57/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0018 - custom_auc: 0.6407 - val_loss: 0.0029 - val_custom_auc: 0.5057

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 21/21 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 8ms/step

# %%
print(roc_auc_score(y>0, y_pred_train.flatten()>0))
print(roc_auc_score(y_val>0, y_pred_val.flatten()>0))
print(roc_auc_score(y_test>0, y_pred_test[:-shift_].flatten()>0))
# Out:
# 0.5371696061734453
# 0.6420454545454546
# 0.5

# %%
print(f'train')
print(count_signs_matrix(y, y_pred_train.flatten()))
print(f'val')
print(count_signs_matrix(y_val, y_pred_val.flatten()))
print(f'test')
print(count_signs_matrix(y_test, y_pred_test[:-shift_].flatten()))
# Out:
# train
# [[167 176]
#  [125 178]]
# val
# [[ 7  1]
#  [13  9]]
# test
# [[ 0 24]
#  [ 0 21]]

# %%
k=-90
m = 2
plot_actual_vs_predicted(y[k:], y_pred_train[k:]*m, y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val*m, y_base0_val)

# %%
plot_actual_vs_predicted(y_test, y_pred_test*m, y_base0_test)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, y_test, y_pred_test[:-shift_], y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, y_test, y_base0_test, y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, y_test, y_base_test, y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.039145  0.002777  0.052699  0.026440  131.510470  1.502203
# Test        0.038757  0.002121  0.046057 -0.094657  111.825966  1.487316
# Validation  0.027471  0.001402  0.037443 -0.006513  373.799808  1.054216
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.039650  0.002853  0.053411 -0.000031  100.0  1.521588
# Test        0.039241  0.002021  0.044954 -0.042823  100.0  1.505902
# Validation  0.027415  0.001435  0.037876 -0.029927  100.0  1.052056
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score         MAPE      MASE
# Train       0.058321  0.005983  0.077351 -1.097411   552.156845  2.238101
# Test        0.036883  0.002296  0.047921 -0.185065   194.894003  1.415398
# Validation  0.052187  0.004144  0.064371 -1.974836  4423.503320  2.002708

# %%
#save model to h5
model.save(prefix+'_lstm_full_cols.h5')
