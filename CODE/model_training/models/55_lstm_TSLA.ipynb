# %% [markdown]
# ### Importy

# %%
pip install shap timeshap ta optuna
# Out:
# Collecting shap
#   Downloading shap-0.44.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (533 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 4.6 MB/s eta 0:00:00
# Collecting timeshap
#   Downloading timeshap-1.0.4-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 8.7 MB/s eta 0:00:00
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting optuna
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 41.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from timeshap) (0.12.2)
# Requirement already satisfied: matplotlib>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from timeshap) (3.7.1)
# Requirement already satisfied: plotly>=4.6 in /usr/local/lib/python3.10/dist-packages (from timeshap) (5.15.0)
# Requirement already satisfied: altair in /usr/local/lib/python3.10/dist-packages (from timeshap) (4.2.2)
# Collecting feedzai-altair-theme (from timeshap)
#   Downloading feedzai_altair_theme-1.1.3-py3-none-any.whl (12 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 29.2 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.23)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.2->timeshap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.6->timeshap) (8.2.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair->timeshap) (0.12.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair->timeshap) (0.15.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.2->timeshap) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair->timeshap) (2.1.3)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29413 sha256=a085a06ad8dc503757c644c2be5f0f506fe36407d9d1a8ad984e01f768099db7
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: slicer, Mako, colorlog, alembic, ta, shap, optuna, feedzai-altair-theme, timeshap
# Successfully installed Mako-1.3.0 alembic-1.13.1 colorlog-6.8.0 feedzai-altair-theme-1.1.3 optuna-3.5.0 shap-0.44.0 slicer-0.0.7 ta-0.11.0 timeshap-1.0.4

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, InputLayer
from keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import optuna
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, InputLayer, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import f1_score, auc
import tensorflow as tf
from tensorflow.keras import backend as K
import itertools
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import shap
from scripts.train_utilities import *
from scripts.essentials import *
from scripts.plots import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, InputLayer
from tensorflow.keras.optimizers import Adam
from keras.models import load_model

# %%
#tf.compat.v1.disable_v2_behavior()

# %%
train_set = pd.read_csv('train_set_full.csv')
test_set = pd.read_csv('test_set_full.csv')
val_set = pd.read_csv('val_set_full.csv')

# %%
prefix = "TSLA"

# %% [markdown]
# ### Funkcje

# %%
def train_model_from_params(params, X, y, X_val, y_val):
  # Create the model
  model = Sequential()

  # Add Conv1D layer if use_conv is True
  if params['use_conv']:
      model.add(Conv1D(filters=params['conv_filters'],
                      kernel_size=params['conv_kernel_size'],
                      activation='relu',
                      input_shape=(X.shape[1], X.shape[2])))
      model.add(MaxPooling1D(pool_size=2))

  # Add LSTM layers
  for i in range(params['n_layers']):
      model.add(LSTM(units=params[f'lstm_units_{i}'],
                    return_sequences=(i < params['n_layers'] - 1)))

  # Add Dense layer and output layer
  model.add(Dense(units=params['dense_units'], activation='relu'))
  model.add(Dense(units=1))

  # Compile the model
  model.compile(optimizer=Adam(learning_rate=params['learning_rate']), loss='mean_squared_error',metrics=[CustomAUCMetric()])

  # Train the model
  early_stopping = EarlyStopping(monitor='val_custom_auc', patience=40, mode='max', restore_best_weights=True)

  history = model.fit(X, y, epochs=350, validation_data=(X_val, y_val),
                          callbacks=[early_stopping])

  return model

class CustomAUCMetric(tf.keras.metrics.Metric):
    def __init__(self, name="custom_auc", **kwargs):
        super(CustomAUCMetric, self).__init__(name=name, **kwargs)
        self.auc = tf.keras.metrics.AUC(from_logits=True)

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true_binary = K.cast(K.greater(y_true, 0), 'float32')
        y_pred_binary = K.cast(K.greater(y_pred, 0), 'float32')
        self.auc.update_state(y_true_binary, y_pred_binary, sample_weight)

    def result(self):
        return self.auc.result()

    def reset_state(self):
        self.auc.reset_states()

def c_f1_score(y_true, y_pred):
    csm = count_signs_matrix(y_true, y_pred)
    #print(csm)
    return (3*csm[1][1]/(csm[1][0]+csm[1][1]+0.001) + 2*csm[1][1]/(csm[0][1]+csm[1][1]+0.001))/5

def custom_f1_metric(y_true, y_pred):
    # Convert y_pred to the same type as y_true
    y_pred = K.cast(y_pred, y_true.dtype)

    # Transform regression outputs to 1 and -1 based on sign
    y_true_binary = K.cast(K.greater(y_true, 0), 'float32')
    y_pred_binary = K.cast(K.greater(y_pred, 0), 'float32')

    # Calculate F1 score
    # Since F1 score is a metric from sklearn, we use tf.py_function to wrap it
    return tf.py_function(c_f1_score, (y_true_binary, y_pred_binary), tf.double)

def custom_auc_metric(y_true, y_pred):
    # Convert y_pred to the same type as y_true
    y_pred = K.cast(y_pred, y_true.dtype)

    # Transform regression outputs to 0 and 1 based on sign
    y_true_sign = K.sign(y_true)
    y_pred_sign = K.sign(y_pred)

    # Use TensorFlow's AUC metric
    return tf.py_function(auc, (y_true_sign, y_pred_sign), tf.double)


def create_model(trial, input_shape):
    model = Sequential()
    model.add(InputLayer(input_shape=input_shape))

    # Optionally add a convolutional layer before LSTM
    if trial.suggest_categorical('use_conv', [True, False]):
        model.add(Conv1D(filters=trial.suggest_categorical('conv_filters', [32, 64, 128]),
                         kernel_size=trial.suggest_int('conv_kernel_size', 2, 5),
                         activation='relu',
                         strides=1,
                      padding='causal'))
        model.add(MaxPooling1D(pool_size=2))

    # Optuna can suggest the number of LSTM layers and units
    n_layers = trial.suggest_int('n_layers', 1, 3)
    for i in range(n_layers):
        model.add(LSTM(units=trial.suggest_categorical(f'lstm_units_{i}', [16, 32, 64]),
                       return_sequences=(i < n_layers - 1)))

    model.add(Dense(units=trial.suggest_categorical('dense_units', [8, 16, 32]), activation='relu'))
    model.add(Dense(units=1))

    # Compile model
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error',metrics=[CustomAUCMetric()])

    return model

def objective(trial):
    model = create_model(trial, input_shape=(X.shape[1], X.shape[2]))

    early_stopping = EarlyStopping(monitor='val_custom_auc', patience=35, mode='max', restore_best_weights=True)

    history = model.fit(X, y, epochs=200, validation_data=(X_val, y_val),
                        callbacks=[early_stopping], verbose=0)

    # Evaluate the model
    val_loss, val_f1 = model.evaluate(X_val, y_val, verbose=0)
    return val_f1

def get_x_y(train_set,
            val_set,
            test_set,
            cols_used,
            target_cols= ['target_5'],
            window_size=10,
            shift_=5):

  X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
  X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
  X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

  y_test = y_test[:-shift_]

  y_base_val = val_set[target_cols[0]].shift(shift_)[window_size:].values
  y_base_test = test_set[target_cols[0]].shift(shift_)[window_size:-shift_].values
  y_base_train = train_set[target_cols[0]].shift(shift_)[window_size:].values
  y_base0_val = [0 for i in range((val_set.shape[0]-window_size))]
  y_base0_train = [0 for i in range((train_set.shape[0]-window_size))]
  y_base0_test = [0 for i in range(len(y_test))]

  return X,y,X_val,y_val,X_test,y_test,y_base_train,y_base_val,y_base_test,y_base0_train,y_base0_val,y_base0_test

# %%
def create_unique_subsets(columns, subset_size=5, min_diff=2):
    """
    Create subsets of columns where each subset differs from every other subset by at least 'min_diff' columns.

    :param columns: List of all columns.
    :param subset_size: The size of each subset.
    :param min_diff: Minimum number of different columns between any two subsets.
    :return: A list of unique subsets.
    """
    all_combinations = list(itertools.combinations(columns, subset_size))
    unique_subsets = []

    for combo in all_combinations:
        if all(len(set(combo) - set(subset)) >= min_diff for subset in unique_subsets):
            unique_subsets.append(combo)

    return unique_subsets

def make_model_better(X, y, X_val, y_val, n_epochs, lstm_units=64, dense_units=10, patience=5):
    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping and model checkpoint
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val), callbacks=[early_stopping, model_checkpoint])

    return model, history

# Example usage:
# model, history = make_model(X_train, y_train, X_val, y_val, n_epochs=50, lstm_units=64, dense_units=10, patience=5)

def window_dataset(df, target_column, window_size):
    X = []
    y = []

    # Iterate over the dataset
    for i in range(len(df) - window_size):
        # Extract the window of data
        window = df[i:i+window_size]

        # Extract the features (X) and target (y)
        X.append(window.drop(columns=[target_column]).values)
        y.append(df[target_column][i+window_size])

    return np.array(X), np.array(y)

def run_multiple_models(train_set,val_set,cols_subset,n_epochs=100):

  window_size = 14
  target_cols = ['target_7']
  mse_val = []
  mse_train = []
  aggregated_shap = []
  for idx,cols_used in enumerate(cols_subset):
    print('-------------------------------')
    print(idx)

    X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
    X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)

    model,history = make_model(X,y, X_val, y_val, n_epochs)

    mse_val.append(min(history.history['val_loss']))
    mse_train.append(min(history.history['loss']))

    explainer = shap.DeepExplainer(model, X)
    shap_values = explainer.shap_values(X_val)

    aggregated_shap.append(np.mean(np.abs(shap_values[0]), axis=0))

    #create df
    if (idx%15 == 0):
      df = pd.DataFrame({'cols_used': cols_subset[:idx+1], 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
      df.to_csv('df_shap'+str(idx)+'.csv')
  df = pd.DataFrame({'cols_used': cols_subset, 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
  df.to_csv('df_shap_final.csv')

  return df

def parse_cols_used(cols_string):
    """
    Parses the column names used in the model from the string representation.

    Args:
    cols_string (str): A string representing the tuple of column names.

    Returns:
    list: A list of column names.
    """
    # Remove the outer brackets and split the string into column names
    cols = cols_string.strip("()").split(", ")
    # Remove quotes and extra characters from column names
    cleaned_cols = [col.strip("'") for col in cols]
    return cleaned_cols

def parse_shap_values(shap_string):
    """
    Parses a string representation of a list of lists of SHAP values into a Python list of lists.

    Args:
    shap_string (str): A string representing a list of lists of SHAP values.

    Returns:
    list of lists: A list of lists of SHAP values.
    """
    # Remove the outer brackets and split the string into rows, handling newline characters
    rows = shap_string.strip('[]').split('\n')

    # Parse each row into a list of floats
    parsed_rows = [list(map(float, row.strip(' []').split())) for row in rows]

    return parsed_rows

def make_model(X, y, n_epochs, lstm_units=32,dense_units=8):
    tf.keras.backend.clear_session()

    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    history = model.fit(X, y, epochs=n_epochs,
                        verbose=0)

    return model, history

def plot_mean_feature_importance(shap_values, feature_names,max_=False):
    """
    Plot the mean importance of each feature across all time steps.

    :param shap_values: A 3D array of SHAP values with shape (samples, window_size, num_features).
    :param feature_names: List of feature names.
    """
    if max_:
    # Aggregate SHAP values across all samples and time steps
      aggregated_shap = np.max(np.abs(shap_values), axis=(0))
    else:
      aggregated_shap = np.mean(np.abs(shap_values), axis=(0))


    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.bar(feature_names, aggregated_shap)
    plt.title('Mean Feature Importance Across All Time Steps')
    plt.ylabel('Mean SHAP Value')
    plt.xlabel('Features')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Optuna

# %%
import random

random.seed(10)
np.random.seed(10)

# Set seed for TensorFlow
tf.random.set_seed(10)

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
             'minmax_low_norm', 'minmax_high_norm', 'norm_rsi_gspc_14', 'norm_slowk_14'
             ]

X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

study_f = optuna.create_study(direction='maximize')
study_f.optimize(objective, n_trials=15)  # Adjust n_trials to how many trials you want to run

print(study_f.best_params)
# Out:
# [I 2023-12-29 14:27:19,389] A new study created in memory with name: no-name-17cafbb8-52b3-4bf2-9a9b-f27f70c16e70
# [I 2023-12-29 14:28:05,530] Trial 0 finished with value: 0.7361111640930176 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 16, 'dense_units': 8, 'learning_rate': 0.00962812949130658}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:28:18,303] Trial 1 finished with value: 0.4999999701976776 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 16, 'learning_rate': 2.047845802877897e-05}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:28:39,426] Trial 2 finished with value: 0.6249999403953552 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 2, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 8, 'learning_rate': 0.006188271400027266}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:29:06,365] Trial 3 finished with value: 0.5555555820465088 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 2, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 32, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 1.2511501631030096e-05}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:29:20,729] Trial 4 finished with value: 0.5416666865348816 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 3, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 0.002433923874005259}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:29:47,208] Trial 5 finished with value: 0.5277777910232544 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 5, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 32, 'lstm_units_2': 32, 'dense_units': 16, 'learning_rate': 1.851812634913613e-05}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:29:59,897] Trial 6 finished with value: 0.638888955116272 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 32, 'learning_rate': 0.00014661559359303177}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:30:26,356] Trial 7 finished with value: 0.5 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 3, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 0.0058183433158276576}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:30:42,068] Trial 8 finished with value: 0.5416666865348816 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 64, 'dense_units': 16, 'learning_rate': 0.00013337596177807518}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:30:57,256] Trial 9 finished with value: 0.6944444179534912 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 32, 'learning_rate': 0.007445023812473422}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:31:22,252] Trial 10 finished with value: 0.5416666865348816 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 16, 'dense_units': 8, 'learning_rate': 0.0007519484434726797}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:31:36,234] Trial 11 finished with value: 0.5416666865348816 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 16, 'dense_units': 8, 'learning_rate': 0.0012869635203514157}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:32:01,461] Trial 12 finished with value: 0.6527777910232544 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 32, 'learning_rate': 0.00894012982724842}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:32:16,192] Trial 13 finished with value: 0.5138888955116272 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 5, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 8, 'learning_rate': 0.002519903305911561}. Best is trial 0 with value: 0.7361111640930176.
# [I 2023-12-29 14:33:04,116] Trial 14 finished with value: 0.5416666865348816 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 32, 'learning_rate': 0.00040490280720291747}. Best is trial 0 with value: 0.7361111640930176.
# {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 16, 'dense_units': 8, 'learning_rate': 0.00962812949130658}

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
            'vader_Score', 'bart_Score', 'mean_influential', 'finbert_Score', 'mean_trustworthy'
             ]

X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

study_n = optuna.create_study(direction='maximize')
study_n.optimize(objective, n_trials=15)  # Adjust n_trials to how many trials you want to run

print(study_n.best_params)
# Out:
# [I 2023-12-29 14:43:11,883] A new study created in memory with name: no-name-021782d3-3f9f-466f-b454-3a7f715ee3dd
# [I 2023-12-29 14:44:20,400] Trial 0 finished with value: 0.4027777910232544 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 4, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 8, 'learning_rate': 2.0800491997236765e-05}. Best is trial 0 with value: 0.4027777910232544.
# [I 2023-12-29 14:44:46,978] Trial 1 finished with value: 0.5 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.00030181069727217854}. Best is trial 1 with value: 0.5.
# [I 2023-12-29 14:44:58,849] Trial 2 finished with value: 0.5833333730697632 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 32, 'learning_rate': 0.0002732469267188306}. Best is trial 2 with value: 0.5833333730697632.
# [I 2023-12-29 14:45:39,696] Trial 3 finished with value: 0.805555522441864 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 64, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 0.0030583566050753266}. Best is trial 3 with value: 0.805555522441864.
# [I 2023-12-29 14:46:26,522] Trial 4 finished with value: 0.638888955116272 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 64, 'lstm_units_2': 64, 'dense_units': 16, 'learning_rate': 8.327744226795445e-05}. Best is trial 3 with value: 0.805555522441864.
# [I 2023-12-29 14:46:54,050] Trial 5 finished with value: 0.9583333730697632 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 32, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 0.0006218390557998092}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:47:14,212] Trial 6 finished with value: 0.819444477558136 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 6.217867859762402e-05}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:47:26,941] Trial 7 finished with value: 0.4722222089767456 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 8, 'learning_rate': 5.334080744675498e-05}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:47:39,648] Trial 8 finished with value: 0.6805555820465088 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 16, 'learning_rate': 9.000837296445601e-05}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:48:06,568] Trial 9 finished with value: 0.7916666269302368 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 32, 'dense_units': 16, 'learning_rate': 0.0011912143356127864}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:48:31,424] Trial 10 finished with value: 0.5833333730697632 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 2, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 32, 'dense_units': 32, 'learning_rate': 0.009509581655197347}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:48:57,388] Trial 11 finished with value: 0.7361111044883728 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 5, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 16, 'lstm_units_2': 32, 'dense_units': 8, 'learning_rate': 0.0008182552425756645}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:49:26,792] Trial 12 finished with value: 0.638888955116272 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 2, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 32, 'dense_units': 32, 'learning_rate': 1.4025831517505972e-05}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:50:55,777] Trial 13 finished with value: 0.7500000596046448 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 16, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 0.0007655624074413871}. Best is trial 5 with value: 0.9583333730697632.
# [I 2023-12-29 14:51:19,464] Trial 14 finished with value: 0.5277777910232544 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 16, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.00021715008779952093}. Best is trial 5 with value: 0.9583333730697632.
# {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 32, 'lstm_units_2': 32, 'dense_units': 32, 'learning_rate': 0.0006218390557998092}

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
            'minmax_low_norm', 'minmax_high_norm', 'norm_rsi_gspc_14', 'norm_slowk_14' ,
            'vader_Score', 'bart_Score', 'mean_influential', 'finbert_Score', 'mean_trustworthy'
             ]

X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
X_test, y_test = window_dataset(test_set[list(cols_used)+target_cols], target_cols[0], window_size)

study_full = optuna.create_study(direction='maximize')
study_full.optimize(objective, n_trials=15)  # Adjust n_trials to how many trials you want to run

print(study_full.best_params)
# Out:
# [I 2023-12-29 14:57:32,110] A new study created in memory with name: no-name-9633210d-3f96-4433-84e6-608df56253af
# [I 2023-12-29 14:58:09,082] Trial 0 finished with value: 0.875 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 32, 'dense_units': 16, 'learning_rate': 0.008145657663991586}. Best is trial 0 with value: 0.875.
# [I 2023-12-29 14:58:22,056] Trial 1 finished with value: 0.5416666865348816 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 3, 'n_layers': 1, 'lstm_units_0': 64, 'dense_units': 16, 'learning_rate': 0.007202350737129768}. Best is trial 0 with value: 0.875.
# [I 2023-12-29 14:58:34,305] Trial 2 finished with value: 0.5 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 3, 'n_layers': 2, 'lstm_units_0': 16, 'lstm_units_1': 32, 'dense_units': 8, 'learning_rate': 1.821365431336809e-05}. Best is trial 0 with value: 0.875.
# [I 2023-12-29 14:59:04,811] Trial 3 finished with value: 0.9027777910232544 and parameters: {'use_conv': False, 'n_layers': 3, 'lstm_units_0': 32, 'lstm_units_1': 16, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 0.003842748098938121}. Best is trial 3 with value: 0.9027777910232544.
# [I 2023-12-29 14:59:27,851] Trial 4 finished with value: 0.8055555820465088 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 64, 'lstm_units_1': 64, 'lstm_units_2': 64, 'dense_units': 32, 'learning_rate': 0.0047742757258318076}. Best is trial 3 with value: 0.9027777910232544.
# [I 2023-12-29 14:59:43,654] Trial 5 finished with value: 0.694444477558136 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 4, 'n_layers': 2, 'lstm_units_0': 64, 'lstm_units_1': 32, 'dense_units': 32, 'learning_rate': 0.00046997776515654175}. Best is trial 3 with value: 0.9027777910232544.
# [I 2023-12-29 15:00:08,824] Trial 6 finished with value: 0.9305555820465088 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 64, 'dense_units': 32, 'learning_rate': 0.0014571180959925705}. Best is trial 6 with value: 0.9305555820465088.
# [I 2023-12-29 15:00:29,948] Trial 7 finished with value: 0.8611111044883728 and parameters: {'use_conv': True, 'conv_filters': 64, 'conv_kernel_size': 2, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 32, 'lstm_units_2': 16, 'dense_units': 32, 'learning_rate': 1.2840508618555844e-05}. Best is trial 6 with value: 0.9305555820465088.
# [I 2023-12-29 15:00:55,356] Trial 8 finished with value: 0.5138888955116272 and parameters: {'use_conv': True, 'conv_filters': 32, 'conv_kernel_size': 3, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 32, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.00013134338620867585}. Best is trial 6 with value: 0.9305555820465088.
# [I 2023-12-29 15:01:27,206] Trial 9 finished with value: 0.5 and parameters: {'use_conv': True, 'conv_filters': 128, 'conv_kernel_size': 4, 'n_layers': 3, 'lstm_units_0': 16, 'lstm_units_1': 64, 'lstm_units_2': 64, 'dense_units': 8, 'learning_rate': 0.0017269129598302584}. Best is trial 6 with value: 0.9305555820465088.
# [I 2023-12-29 15:01:40,002] Trial 10 finished with value: 0.7083332538604736 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 32, 'learning_rate': 0.000561662625388336}. Best is trial 6 with value: 0.9305555820465088.
# [I 2023-12-29 15:02:25,243] Trial 11 finished with value: 0.9583333730697632 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 16, 'dense_units': 32, 'learning_rate': 0.0016630031137850364}. Best is trial 11 with value: 0.9583333730697632.
# [I 2023-12-29 15:02:43,010] Trial 12 finished with value: 0.875 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 16, 'dense_units': 32, 'learning_rate': 0.0012567151507481174}. Best is trial 11 with value: 0.9583333730697632.
# [I 2023-12-29 15:02:55,715] Trial 13 finished with value: 0.5277777910232544 and parameters: {'use_conv': False, 'n_layers': 1, 'lstm_units_0': 32, 'dense_units': 32, 'learning_rate': 0.00015340212763651658}. Best is trial 11 with value: 0.9583333730697632.
# [I 2023-12-29 15:03:20,284] Trial 14 finished with value: 0.9166666269302368 and parameters: {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 16, 'dense_units': 32, 'learning_rate': 0.0022187017888454304}. Best is trial 11 with value: 0.9583333730697632.
# {'use_conv': False, 'n_layers': 2, 'lstm_units_0': 32, 'lstm_units_1': 16, 'dense_units': 32, 'learning_rate': 0.0016630031137850364}

# %% [markdown]
# ### Model Finance

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
             'minmax_low_norm', 'minmax_high_norm', 'norm_rsi_gspc_14', 'norm_slowk_14'
             ]
shift_ = 5

X, y, X_val, y_val, X_test, y_test, y_base_train, y_base_val, y_base_test,\
y_base0_train, y_base0_val, y_base0_test = get_x_y(train_set = train_set,
        val_set = val_set, test_set = test_set, cols_used = cols_used,
        target_cols= target_cols, window_size=10, shift_= shift_)

# %%
model = train_model_from_params(study_f.best_params, X, y, X_val, y_val)
# Out:
# Epoch 1/350
# 21/21 [==============================] - 6s 65ms/step - loss: 0.0090 - custom_auc: 0.5077 - val_loss: 0.0038 - val_custom_auc: 0.5000
# Epoch 2/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0071 - custom_auc: 0.5292 - val_loss: 0.0041 - val_custom_auc: 0.5000
# Epoch 3/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5333 - val_loss: 0.0037 - val_custom_auc: 0.3889
# Epoch 4/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.5134 - val_loss: 0.0035 - val_custom_auc: 0.5139
# Epoch 5/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0068 - custom_auc: 0.5392 - val_loss: 0.0035 - val_custom_auc: 0.4167
# Epoch 6/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5073 - val_loss: 0.0037 - val_custom_auc: 0.3750
# Epoch 7/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5502 - val_loss: 0.0048 - val_custom_auc: 0.5000
# Epoch 8/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0071 - custom_auc: 0.5110 - val_loss: 0.0034 - val_custom_auc: 0.5000
# Epoch 9/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0068 - custom_auc: 0.5503 - val_loss: 0.0034 - val_custom_auc: 0.4861
# Epoch 10/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0067 - custom_auc: 0.5459 - val_loss: 0.0036 - val_custom_auc: 0.4861
# Epoch 11/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0067 - custom_auc: 0.5324 - val_loss: 0.0034 - val_custom_auc: 0.5000
# Epoch 12/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0068 - custom_auc: 0.5326 - val_loss: 0.0031 - val_custom_auc: 0.4306
# Epoch 13/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0067 - custom_auc: 0.5530 - val_loss: 0.0037 - val_custom_auc: 0.4028
# Epoch 14/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0068 - custom_auc: 0.5568 - val_loss: 0.0034 - val_custom_auc: 0.4861
# Epoch 15/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0067 - custom_auc: 0.5361 - val_loss: 0.0036 - val_custom_auc: 0.5417
# Epoch 16/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0067 - custom_auc: 0.5405 - val_loss: 0.0039 - val_custom_auc: 0.5139
# Epoch 17/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0066 - custom_auc: 0.5539 - val_loss: 0.0032 - val_custom_auc: 0.5417
# Epoch 18/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0066 - custom_auc: 0.5703 - val_loss: 0.0034 - val_custom_auc: 0.6250
# Epoch 19/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0066 - custom_auc: 0.5609 - val_loss: 0.0034 - val_custom_auc: 0.5972
# Epoch 20/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0065 - custom_auc: 0.6009 - val_loss: 0.0045 - val_custom_auc: 0.3750
# Epoch 21/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0068 - custom_auc: 0.5215 - val_loss: 0.0034 - val_custom_auc: 0.6250
# Epoch 22/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0068 - custom_auc: 0.5431 - val_loss: 0.0035 - val_custom_auc: 0.4861
# Epoch 23/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - custom_auc: 0.5410 - val_loss: 0.0035 - val_custom_auc: 0.4583
# Epoch 24/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0066 - custom_auc: 0.5582 - val_loss: 0.0034 - val_custom_auc: 0.5972
# Epoch 25/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0066 - custom_auc: 0.5356 - val_loss: 0.0040 - val_custom_auc: 0.4861
# Epoch 26/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0068 - custom_auc: 0.5430 - val_loss: 0.0033 - val_custom_auc: 0.4583
# Epoch 27/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0065 - custom_auc: 0.5589 - val_loss: 0.0032 - val_custom_auc: 0.5000
# Epoch 28/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0065 - custom_auc: 0.5754 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 29/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0065 - custom_auc: 0.5672 - val_loss: 0.0035 - val_custom_auc: 0.4583
# Epoch 30/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0064 - custom_auc: 0.5810 - val_loss: 0.0036 - val_custom_auc: 0.5139
# Epoch 31/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0064 - custom_auc: 0.5655 - val_loss: 0.0040 - val_custom_auc: 0.5139
# Epoch 32/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0062 - custom_auc: 0.6098 - val_loss: 0.0044 - val_custom_auc: 0.4861
# Epoch 33/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0064 - custom_auc: 0.5530 - val_loss: 0.0041 - val_custom_auc: 0.5139
# Epoch 34/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0063 - custom_auc: 0.5773 - val_loss: 0.0050 - val_custom_auc: 0.6250
# Epoch 35/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0066 - custom_auc: 0.5819 - val_loss: 0.0037 - val_custom_auc: 0.4583
# Epoch 36/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0061 - custom_auc: 0.5741 - val_loss: 0.0048 - val_custom_auc: 0.4583
# Epoch 37/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0067 - custom_auc: 0.5636 - val_loss: 0.0043 - val_custom_auc: 0.4861
# Epoch 38/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - custom_auc: 0.5531 - val_loss: 0.0049 - val_custom_auc: 0.5417
# Epoch 39/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0064 - custom_auc: 0.5704 - val_loss: 0.0035 - val_custom_auc: 0.4861
# Epoch 40/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0063 - custom_auc: 0.5937 - val_loss: 0.0038 - val_custom_auc: 0.4861
# Epoch 41/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - custom_auc: 0.6066 - val_loss: 0.0040 - val_custom_auc: 0.4028
# Epoch 42/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0063 - custom_auc: 0.5487 - val_loss: 0.0046 - val_custom_auc: 0.4861
# Epoch 43/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0063 - custom_auc: 0.5805 - val_loss: 0.0031 - val_custom_auc: 0.5972
# Epoch 44/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0061 - custom_auc: 0.6003 - val_loss: 0.0039 - val_custom_auc: 0.6250
# Epoch 45/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0062 - custom_auc: 0.5909 - val_loss: 0.0034 - val_custom_auc: 0.4861
# Epoch 46/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0060 - custom_auc: 0.6064 - val_loss: 0.0057 - val_custom_auc: 0.5000
# Epoch 47/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0065 - custom_auc: 0.5902 - val_loss: 0.0035 - val_custom_auc: 0.4028
# Epoch 48/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0061 - custom_auc: 0.5879 - val_loss: 0.0046 - val_custom_auc: 0.3194
# Epoch 49/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - custom_auc: 0.5621 - val_loss: 0.0037 - val_custom_auc: 0.5417
# Epoch 50/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0059 - custom_auc: 0.6181 - val_loss: 0.0036 - val_custom_auc: 0.5417
# Epoch 51/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0059 - custom_auc: 0.6151 - val_loss: 0.0045 - val_custom_auc: 0.5139
# Epoch 52/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0061 - custom_auc: 0.5878 - val_loss: 0.0042 - val_custom_auc: 0.4861
# Epoch 53/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0058 - custom_auc: 0.6099 - val_loss: 0.0041 - val_custom_auc: 0.5139
# Epoch 54/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0059 - custom_auc: 0.6118 - val_loss: 0.0045 - val_custom_auc: 0.5000
# Epoch 55/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0060 - custom_auc: 0.5972 - val_loss: 0.0053 - val_custom_auc: 0.5694
# Epoch 56/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0057 - custom_auc: 0.6187 - val_loss: 0.0053 - val_custom_auc: 0.6528
# Epoch 57/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0059 - custom_auc: 0.6151 - val_loss: 0.0035 - val_custom_auc: 0.3611
# Epoch 58/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0057 - custom_auc: 0.5930 - val_loss: 0.0042 - val_custom_auc: 0.4583
# Epoch 59/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0056 - custom_auc: 0.6277 - val_loss: 0.0051 - val_custom_auc: 0.6111
# Epoch 60/350
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0062 - custom_auc: 0.5909 - val_loss: 0.0034 - val_custom_auc: 0.4583
# Epoch 61/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0062 - custom_auc: 0.5729 - val_loss: 0.0081 - val_custom_auc: 0.5139
# Epoch 62/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - custom_auc: 0.5163 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 63/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4918 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 64/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5011 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 65/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0070 - custom_auc: 0.4870 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 66/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - custom_auc: 0.5006 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 67/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0072 - custom_auc: 0.4760 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 68/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0068 - custom_auc: 0.5294 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 69/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0069 - custom_auc: 0.4780 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 70/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5190 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 71/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0071 - custom_auc: 0.4887 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 72/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0069 - custom_auc: 0.5062 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 73/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0069 - custom_auc: 0.4979 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 74/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0069 - custom_auc: 0.5066 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 75/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5060 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 76/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4795 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 77/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0072 - custom_auc: 0.4939 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 78/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0069 - custom_auc: 0.5128 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 79/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0070 - custom_auc: 0.4959 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 80/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - custom_auc: 0.5143 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 81/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4799 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 82/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0070 - custom_auc: 0.4797 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 83/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4880 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 84/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0070 - custom_auc: 0.4946 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 85/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4996 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 86/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4724 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 87/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.4872 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 88/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0070 - custom_auc: 0.4704 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 89/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0072 - custom_auc: 0.5159 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 90/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - custom_auc: 0.4893 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 91/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - custom_auc: 0.4810 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 92/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0069 - custom_auc: 0.5054 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 93/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - custom_auc: 0.4911 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 94/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0070 - custom_auc: 0.4530 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 95/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0069 - custom_auc: 0.4812 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 96/350
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0069 - custom_auc: 0.5120 - val_loss: 0.0036 - val_custom_auc: 0.5000

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 788ms/step
# 21/21 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 8ms/step

# %%
print(roc_auc_score(y>0, y_pred_train.flatten()>0))
print(roc_auc_score(y_val>0, y_pred_val.flatten()>0))
print(roc_auc_score(y_test>0, y_pred_test[:-shift_].flatten()>0))
# Out:
# 0.5831215901354837
# 0.6527777777777777
# 0.3310276679841897

# %%
print(f'train')
print(count_signs_matrix(y, y_pred_train.flatten()))
print(f'val')
print(count_signs_matrix(y_val, y_pred_val.flatten()))
print(f'test')
print(count_signs_matrix(y_test, y_pred_test[:-shift_].flatten()))
# Out:
# train
# [[255  74]
#  [193 124]]
# val
# [[11  1]
#  [11  7]]
# test
# [[10 13]
#  [17  5]]

# %%
k=-90
m = 1
plot_actual_vs_predicted(y[k:], y_pred_train[k:]*m, y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val*m, y_base0_val)

# %%
plot_actual_vs_predicted(y_test, y_pred_test*m, y_base0_test)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, y_test, y_pred_test[:-shift_], y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, y_test, y_base0_test, y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, y_test, y_base_test, y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.061783  0.005936  0.077048  0.141115  674.921596  1.531723
# Test        0.085351  0.011153  0.105608 -0.889140  207.088216  2.116009
# Validation  0.054255  0.005336  0.073046 -0.544996  278.881945  1.345085
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.064894  0.006912  0.083137 -0.000003  100.0  1.608834
# Test        0.062652  0.006008  0.077513 -0.017686  100.0  1.553260
# Validation  0.049144  0.003530  0.059411 -0.022058  100.0  1.218378
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.085557  0.011935  0.109245 -0.726724  783.969031  2.121111
# Test        0.092328  0.010375  0.101858 -0.757355  366.240721  2.288971
# Validation  0.065605  0.006689  0.081784 -0.936777  545.417382  1.626482

# %%
#save model to h5
model.save(prefix+'_lstm_fin_cols.h5')

# %% [markdown]
# ### Model News

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
            'vader_Score', 'bart_Score', 'mean_influential', 'finbert_Score', 'mean_trustworthy'
             ]
shift_ = 5

X, y, X_val, y_val, X_test, y_test, y_base_train, y_base_val, y_base_test,\
y_base0_train, y_base0_val, y_base0_test = get_x_y(train_set = train_set,
        val_set = val_set, test_set = test_set, cols_used = cols_used,
        target_cols= target_cols, window_size=10, shift_= shift_)

# %%
model = train_model_from_params(study_n.best_params, X, y, X_val, y_val)
# Out:
# Epoch 1/350
# 21/21 [==============================] - 8s 115ms/step - loss: 0.0069 - custom_auc: 0.4918 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 2/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0070 - custom_auc: 0.4882 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 3/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0069 - custom_auc: 0.5145 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 4/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0070 - custom_auc: 0.4878 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 5/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0069 - custom_auc: 0.4989 - val_loss: 0.0036 - val_custom_auc: 0.2222
# Epoch 6/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0069 - custom_auc: 0.5271 - val_loss: 0.0037 - val_custom_auc: 0.4167
# Epoch 7/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0069 - custom_auc: 0.5252 - val_loss: 0.0035 - val_custom_auc: 0.4861
# Epoch 8/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0069 - custom_auc: 0.5333 - val_loss: 0.0037 - val_custom_auc: 0.2361
# Epoch 9/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0068 - custom_auc: 0.5375 - val_loss: 0.0036 - val_custom_auc: 0.4167
# Epoch 10/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0067 - custom_auc: 0.5278 - val_loss: 0.0040 - val_custom_auc: 0.2778
# Epoch 11/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0068 - custom_auc: 0.5162 - val_loss: 0.0038 - val_custom_auc: 0.3750
# Epoch 12/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0067 - custom_auc: 0.5302 - val_loss: 0.0039 - val_custom_auc: 0.3889
# Epoch 13/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0066 - custom_auc: 0.5378 - val_loss: 0.0038 - val_custom_auc: 0.4167
# Epoch 14/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0065 - custom_auc: 0.5531 - val_loss: 0.0040 - val_custom_auc: 0.4444
# Epoch 15/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0065 - custom_auc: 0.5409 - val_loss: 0.0038 - val_custom_auc: 0.4167
# Epoch 16/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0063 - custom_auc: 0.5656 - val_loss: 0.0039 - val_custom_auc: 0.5000
# Epoch 17/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0063 - custom_auc: 0.6117 - val_loss: 0.0035 - val_custom_auc: 0.4167
# Epoch 18/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0059 - custom_auc: 0.5978 - val_loss: 0.0034 - val_custom_auc: 0.4861
# Epoch 19/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0056 - custom_auc: 0.6079 - val_loss: 0.0032 - val_custom_auc: 0.5417
# Epoch 20/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0054 - custom_auc: 0.6335 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 21/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0051 - custom_auc: 0.6464 - val_loss: 0.0028 - val_custom_auc: 0.7222
# Epoch 22/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0050 - custom_auc: 0.6371 - val_loss: 0.0030 - val_custom_auc: 0.5417
# Epoch 23/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0047 - custom_auc: 0.6574 - val_loss: 0.0037 - val_custom_auc: 0.4444
# Epoch 24/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0047 - custom_auc: 0.6416 - val_loss: 0.0030 - val_custom_auc: 0.6528
# Epoch 25/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0050 - custom_auc: 0.6421 - val_loss: 0.0030 - val_custom_auc: 0.5694
# Epoch 26/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0046 - custom_auc: 0.6440 - val_loss: 0.0048 - val_custom_auc: 0.5556
# Epoch 27/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0043 - custom_auc: 0.6653 - val_loss: 0.0033 - val_custom_auc: 0.6389
# Epoch 28/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0043 - custom_auc: 0.6550 - val_loss: 0.0039 - val_custom_auc: 0.5694
# Epoch 29/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0042 - custom_auc: 0.6758 - val_loss: 0.0032 - val_custom_auc: 0.5417
# Epoch 30/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0040 - custom_auc: 0.7007 - val_loss: 0.0028 - val_custom_auc: 0.5833
# Epoch 31/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0042 - custom_auc: 0.6715 - val_loss: 0.0025 - val_custom_auc: 0.6528
# Epoch 32/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0041 - custom_auc: 0.6856 - val_loss: 0.0031 - val_custom_auc: 0.5417
# Epoch 33/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0042 - custom_auc: 0.6736 - val_loss: 0.0042 - val_custom_auc: 0.5833
# Epoch 34/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0038 - custom_auc: 0.6946 - val_loss: 0.0040 - val_custom_auc: 0.5417
# Epoch 35/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0037 - custom_auc: 0.7119 - val_loss: 0.0038 - val_custom_auc: 0.6250
# Epoch 36/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0037 - custom_auc: 0.6949 - val_loss: 0.0044 - val_custom_auc: 0.5417
# Epoch 37/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0037 - custom_auc: 0.7137 - val_loss: 0.0055 - val_custom_auc: 0.5000
# Epoch 38/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0040 - custom_auc: 0.7052 - val_loss: 0.0035 - val_custom_auc: 0.5000
# Epoch 39/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0035 - custom_auc: 0.7117 - val_loss: 0.0027 - val_custom_auc: 0.6250
# Epoch 40/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0035 - custom_auc: 0.7297 - val_loss: 0.0037 - val_custom_auc: 0.6111
# Epoch 41/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0035 - custom_auc: 0.7136 - val_loss: 0.0040 - val_custom_auc: 0.5694
# Epoch 42/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0034 - custom_auc: 0.7027 - val_loss: 0.0037 - val_custom_auc: 0.5000
# Epoch 43/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0031 - custom_auc: 0.7304 - val_loss: 0.0039 - val_custom_auc: 0.5972
# Epoch 44/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0031 - custom_auc: 0.7196 - val_loss: 0.0039 - val_custom_auc: 0.5972
# Epoch 45/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0032 - custom_auc: 0.7258 - val_loss: 0.0027 - val_custom_auc: 0.6250
# Epoch 46/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0031 - custom_auc: 0.7322 - val_loss: 0.0036 - val_custom_auc: 0.5000
# Epoch 47/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0031 - custom_auc: 0.7445 - val_loss: 0.0052 - val_custom_auc: 0.5000
# Epoch 48/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0033 - custom_auc: 0.7376 - val_loss: 0.0027 - val_custom_auc: 0.6389
# Epoch 49/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0029 - custom_auc: 0.7325 - val_loss: 0.0031 - val_custom_auc: 0.5972
# Epoch 50/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0028 - custom_auc: 0.7543 - val_loss: 0.0032 - val_custom_auc: 0.5694
# Epoch 51/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0029 - custom_auc: 0.7509 - val_loss: 0.0039 - val_custom_auc: 0.5139
# Epoch 52/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0028 - custom_auc: 0.7451 - val_loss: 0.0042 - val_custom_auc: 0.5556
# Epoch 53/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0026 - custom_auc: 0.7571 - val_loss: 0.0036 - val_custom_auc: 0.5278
# Epoch 54/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0025 - custom_auc: 0.7775 - val_loss: 0.0031 - val_custom_auc: 0.5694
# Epoch 55/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0031 - custom_auc: 0.7439 - val_loss: 0.0047 - val_custom_auc: 0.5694
# Epoch 56/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0028 - custom_auc: 0.7587 - val_loss: 0.0038 - val_custom_auc: 0.5000
# Epoch 57/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0027 - custom_auc: 0.7839 - val_loss: 0.0066 - val_custom_auc: 0.5139
# Epoch 58/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0026 - custom_auc: 0.7708 - val_loss: 0.0047 - val_custom_auc: 0.5000
# Epoch 59/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0028 - custom_auc: 0.7465 - val_loss: 0.0040 - val_custom_auc: 0.4722
# Epoch 60/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0024 - custom_auc: 0.7680 - val_loss: 0.0049 - val_custom_auc: 0.4861
# Epoch 61/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0024 - custom_auc: 0.7758 - val_loss: 0.0043 - val_custom_auc: 0.5278

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 21/21 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y>0, y_pred_train.flatten()>0))
print(roc_auc_score(y_val>0, y_pred_val.flatten()>0))
print(roc_auc_score(y_test>0, y_pred_test[:-shift_].flatten()>0))
# Out:
# 0.651875005992732
# 0.7222222222222223
# 0.39723320158102765

# %%
print(f'train')
print(count_signs_matrix(y, y_pred_train.flatten()))
print(f'val')
print(count_signs_matrix(y_val, y_pred_val.flatten()))
print(f'test')
print(count_signs_matrix(y_test, y_pred_test[:-shift_].flatten()))
# Out:
# train
# [[184 145]
#  [ 81 236]]
# val
# [[10  2]
#  [ 7 11]]
# test
# [[12 11]
#  [16  6]]

# %%
k=-90
m = 1
plot_actual_vs_predicted(y[k:], y_pred_train[k:]*m, y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val*m, y_base0_val)

# %%
plot_actual_vs_predicted(y_test, y_pred_test*m, y_base0_test)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, y_test, y_pred_test[:-shift_], y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, y_test, y_base0_test, y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, y_test, y_base_test, y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.054482  0.004778  0.069127  0.308636  588.096251  1.350720
# Test        0.069242  0.007728  0.087909 -0.308978  137.361608  1.716639
# Validation  0.043993  0.002792  0.052844  0.191409  163.652910  1.090664
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.064894  0.006912  0.083137 -0.000003  100.0  1.608834
# Test        0.062652  0.006008  0.077513 -0.017686  100.0  1.553260
# Validation  0.049144  0.003530  0.059411 -0.022058  100.0  1.218378
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.085557  0.011935  0.109245 -0.726724  783.969031  2.121111
# Test        0.092328  0.010375  0.101858 -0.757355  366.240721  2.288971
# Validation  0.065605  0.006689  0.081784 -0.936777  545.417382  1.626482

# %%
#save model to h5
model.save(prefix+'_lstm_news_cols.h5')

# %% [markdown]
# ### Model Full

# %%
window_size = 10
target_cols = ['target_5']
cols_used = [
            'minmax_low_norm', 'minmax_high_norm', 'norm_rsi_gspc_14', 'norm_slowk_14' ,
            'vader_Score', 'bart_Score', 'mean_influential', 'finbert_Score', 'mean_trustworthy'
             ]
shift_ = 5

X, y, X_val, y_val, X_test, y_test, y_base_train, y_base_val, y_base_test,\
y_base0_train, y_base0_val, y_base0_test = get_x_y(train_set = train_set,
        val_set = val_set, test_set = test_set, cols_used = cols_used,
        target_cols= target_cols, window_size=10, shift_= shift_)

# %%
model = train_model_from_params(study_full.best_params, X, y, X_val, y_val)
# Out:
# Epoch 1/350
# 21/21 [==============================] - 7s 70ms/step - loss: 0.0071 - custom_auc: 0.5363 - val_loss: 0.0033 - val_custom_auc: 0.5417
# Epoch 2/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0067 - custom_auc: 0.5475 - val_loss: 0.0040 - val_custom_auc: 0.5000
# Epoch 3/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0066 - custom_auc: 0.5723 - val_loss: 0.0036 - val_custom_auc: 0.4861
# Epoch 4/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0065 - custom_auc: 0.5703 - val_loss: 0.0031 - val_custom_auc: 0.6528
# Epoch 5/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0063 - custom_auc: 0.6030 - val_loss: 0.0032 - val_custom_auc: 0.5139
# Epoch 6/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0067 - custom_auc: 0.5709 - val_loss: 0.0033 - val_custom_auc: 0.5000
# Epoch 7/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0062 - custom_auc: 0.6116 - val_loss: 0.0041 - val_custom_auc: 0.4861
# Epoch 8/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0065 - custom_auc: 0.5611 - val_loss: 0.0043 - val_custom_auc: 0.5000
# Epoch 9/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0063 - custom_auc: 0.6132 - val_loss: 0.0031 - val_custom_auc: 0.5833
# Epoch 10/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0060 - custom_auc: 0.6236 - val_loss: 0.0031 - val_custom_auc: 0.5139
# Epoch 11/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0060 - custom_auc: 0.5978 - val_loss: 0.0039 - val_custom_auc: 0.5139
# Epoch 12/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0062 - custom_auc: 0.6113 - val_loss: 0.0031 - val_custom_auc: 0.5972
# Epoch 13/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0060 - custom_auc: 0.6035 - val_loss: 0.0028 - val_custom_auc: 0.6667
# Epoch 14/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0060 - custom_auc: 0.6307 - val_loss: 0.0030 - val_custom_auc: 0.6389
# Epoch 15/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0058 - custom_auc: 0.6330 - val_loss: 0.0026 - val_custom_auc: 0.7639
# Epoch 16/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0065 - custom_auc: 0.5725 - val_loss: 0.0043 - val_custom_auc: 0.5139
# Epoch 17/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0058 - custom_auc: 0.6331 - val_loss: 0.0029 - val_custom_auc: 0.8750
# Epoch 18/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0057 - custom_auc: 0.6199 - val_loss: 0.0025 - val_custom_auc: 0.8472
# Epoch 19/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0055 - custom_auc: 0.6392 - val_loss: 0.0023 - val_custom_auc: 0.7917
# Epoch 20/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0056 - custom_auc: 0.6264 - val_loss: 0.0024 - val_custom_auc: 0.8750
# Epoch 21/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0053 - custom_auc: 0.6272 - val_loss: 0.0022 - val_custom_auc: 0.8889
# Epoch 22/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0053 - custom_auc: 0.6436 - val_loss: 0.0022 - val_custom_auc: 0.9028
# Epoch 23/350
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0053 - custom_auc: 0.6418 - val_loss: 0.0023 - val_custom_auc: 0.8194
# Epoch 24/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0051 - custom_auc: 0.6577 - val_loss: 0.0029 - val_custom_auc: 0.7639
# Epoch 25/350
# 21/21 [==============================] - 0s 19ms/step - loss: 0.0054 - custom_auc: 0.6112 - val_loss: 0.0026 - val_custom_auc: 0.8194
# Epoch 26/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0055 - custom_auc: 0.6415 - val_loss: 0.0029 - val_custom_auc: 0.7361
# Epoch 27/350
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0052 - custom_auc: 0.6655 - val_loss: 0.0023 - val_custom_auc: 0.7778
# Epoch 28/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0054 - custom_auc: 0.6216 - val_loss: 0.0023 - val_custom_auc: 0.7917
# Epoch 29/350
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0050 - custom_auc: 0.6687 - val_loss: 0.0028 - val_custom_auc: 0.7917
# Epoch 30/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0051 - custom_auc: 0.6630 - val_loss: 0.0024 - val_custom_auc: 0.8194
# Epoch 31/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0049 - custom_auc: 0.6679 - val_loss: 0.0020 - val_custom_auc: 0.8472
# Epoch 32/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0049 - custom_auc: 0.6477 - val_loss: 0.0027 - val_custom_auc: 0.6389
# Epoch 33/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0047 - custom_auc: 0.6773 - val_loss: 0.0022 - val_custom_auc: 0.8889
# Epoch 34/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0047 - custom_auc: 0.6941 - val_loss: 0.0022 - val_custom_auc: 0.8889
# Epoch 35/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0047 - custom_auc: 0.6479 - val_loss: 0.0022 - val_custom_auc: 0.9028
# Epoch 36/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0046 - custom_auc: 0.6825 - val_loss: 0.0022 - val_custom_auc: 0.8194
# Epoch 37/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0051 - custom_auc: 0.6701 - val_loss: 0.0020 - val_custom_auc: 0.8750
# Epoch 38/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0046 - custom_auc: 0.6981 - val_loss: 0.0021 - val_custom_auc: 0.9028
# Epoch 39/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0047 - custom_auc: 0.6884 - val_loss: 0.0022 - val_custom_auc: 0.9028
# Epoch 40/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0044 - custom_auc: 0.6760 - val_loss: 0.0029 - val_custom_auc: 0.6806
# Epoch 41/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0043 - custom_auc: 0.6864 - val_loss: 0.0023 - val_custom_auc: 0.8194
# Epoch 42/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0045 - custom_auc: 0.6771 - val_loss: 0.0032 - val_custom_auc: 0.6806
# Epoch 43/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0043 - custom_auc: 0.6757 - val_loss: 0.0029 - val_custom_auc: 0.7917
# Epoch 44/350
# 21/21 [==============================] - 0s 17ms/step - loss: 0.0043 - custom_auc: 0.6881 - val_loss: 0.0025 - val_custom_auc: 0.8194
# Epoch 45/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0041 - custom_auc: 0.7196 - val_loss: 0.0030 - val_custom_auc: 0.6944
# Epoch 46/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0039 - custom_auc: 0.7084 - val_loss: 0.0027 - val_custom_auc: 0.8056
# Epoch 47/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0042 - custom_auc: 0.6890 - val_loss: 0.0028 - val_custom_auc: 0.7639
# Epoch 48/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0038 - custom_auc: 0.7079 - val_loss: 0.0040 - val_custom_auc: 0.6806
# Epoch 49/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0039 - custom_auc: 0.7083 - val_loss: 0.0030 - val_custom_auc: 0.8472
# Epoch 50/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0040 - custom_auc: 0.7127 - val_loss: 0.0035 - val_custom_auc: 0.6389
# Epoch 51/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0039 - custom_auc: 0.7095 - val_loss: 0.0031 - val_custom_auc: 0.7639
# Epoch 52/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0041 - custom_auc: 0.7003 - val_loss: 0.0030 - val_custom_auc: 0.8333
# Epoch 53/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0039 - custom_auc: 0.7085 - val_loss: 0.0042 - val_custom_auc: 0.5694
# Epoch 54/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0035 - custom_auc: 0.7252 - val_loss: 0.0031 - val_custom_auc: 0.7917
# Epoch 55/350
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0034 - custom_auc: 0.7298 - val_loss: 0.0043 - val_custom_auc: 0.5278
# Epoch 56/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0035 - custom_auc: 0.7470 - val_loss: 0.0039 - val_custom_auc: 0.7500
# Epoch 57/350
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0035 - custom_auc: 0.7266 - val_loss: 0.0040 - val_custom_auc: 0.7778
# Epoch 58/350
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0034 - custom_auc: 0.7376 - val_loss: 0.0041 - val_custom_auc: 0.6667
# Epoch 59/350
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0032 - custom_auc: 0.7249 - val_loss: 0.0051 - val_custom_auc: 0.7083
# Epoch 60/350
# 21/21 [==============================] - 0s 18ms/step - loss: 0.0033 - custom_auc: 0.7371 - val_loss: 0.0042 - val_custom_auc: 0.5833
# Epoch 61/350
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0033 - custom_auc: 0.7210 - val_loss: 0.0031 - val_custom_auc: 0.8472
# Epoch 62/350
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0033 - custom_auc: 0.7640 - val_loss: 0.0046 - val_custom_auc: 0.7083

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)
y_pred_test = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 21/21 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 6ms/step

# %%
print(roc_auc_score(y>0, y_pred_train.flatten()>0))
print(roc_auc_score(y_val>0, y_pred_val.flatten()>0))
print(roc_auc_score(y_test>0, y_pred_test[:-shift_].flatten()>0))
# Out:
# 0.6886368212631719
# 0.9027777777777777
# 0.3349802371541502

# %%
print(f'train')
print(count_signs_matrix(y, y_pred_train.flatten()))
print(f'val')
print(count_signs_matrix(y_val, y_pred_val.flatten()))
print(f'test')
print(count_signs_matrix(y_test, y_pred_test[:-shift_].flatten()))
# Out:
# train
# [[203 126]
#  [ 76 241]]
# val
# [[11  1]
#  [ 2 16]]
# test
# [[ 6 17]
#  [13  9]]

# %%
k=-90
m = 2
plot_actual_vs_predicted(y[k:], y_pred_train[k:]*m, y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val*m, y_base0_val)

# %%
plot_actual_vs_predicted(y_test, y_pred_test*m, y_base0_test)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, y_test, y_pred_test[:-shift_], y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, y_test, y_base0_test, y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, y_test, y_base_test, y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.056569  0.005005  0.070745  0.275879  618.588614  1.402442
# Test        0.074176  0.008620  0.092842 -0.460020  177.232850  1.838967
# Validation  0.032228  0.002183  0.046725  0.367820  224.885677  0.798981
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.064894  0.006912  0.083137 -0.000003  100.0  1.608834
# Test        0.062652  0.006008  0.077513 -0.017686  100.0  1.553260
# Validation  0.049144  0.003530  0.059411 -0.022058  100.0  1.218378
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.085557  0.011935  0.109245 -0.726724  783.969031  2.121111
# Test        0.092328  0.010375  0.101858 -0.757355  366.240721  2.288971
# Validation  0.065605  0.006689  0.081784 -0.936777  545.417382  1.626482

# %%
#save model to h5
model.save(prefix+'_lstm_full_cols.h5')
