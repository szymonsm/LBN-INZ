# %% [markdown]
# ### Importy

# %%
pip install ta shap timeshap

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, InputLayer
from keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import itertools
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import shap
from scripts.train_utilities import *
from scripts.essentials import *
from scripts.plots import *
from keras.models import load_model

# %%
tf.compat.v1.disable_v2_behavior()

# %%
train_set = pd.read_csv('train_set_full.csv')
test_set = pd.read_csv('test_set_full.csv')
val_set = pd.read_csv('val_set_full.csv')

# %%
#zmienione do szymona
row_to_add = val_set[:5]
train_set = train_set.append(row_to_add, ignore_index=True)
val_set = val_set[5:]
val_set.reset_index(drop=True, inplace=True)
row_to_add = test_set[:1]
val_set = val_set.append(row_to_add, ignore_index=True)
test_set = test_set[1:]

# %%
prefix = "NFLX"

# %% [markdown]
# ### Funkcje

# %%
def create_unique_subsets(columns, subset_size=5, min_diff=2):
    """
    Create subsets of columns where each subset differs from every other subset by at least 'min_diff' columns.

    :param columns: List of all columns.
    :param subset_size: The size of each subset.
    :param min_diff: Minimum number of different columns between any two subsets.
    :return: A list of unique subsets.
    """
    all_combinations = list(itertools.combinations(columns, subset_size))
    unique_subsets = []

    for combo in all_combinations:
        if all(len(set(combo) - set(subset)) >= min_diff for subset in unique_subsets):
            unique_subsets.append(combo)

    return unique_subsets

def make_model_better(X, y, X_val, y_val, n_epochs, lstm_units=64, dense_units=10, patience=5):
    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping and model checkpoint
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val), callbacks=[early_stopping, model_checkpoint])

    return model, history

# Example usage:
# model, history = make_model(X_train, y_train, X_val, y_val, n_epochs=50, lstm_units=64, dense_units=10, patience=5)

def window_dataset(df, target_column, window_size):
    X = []
    y = []

    # Iterate over the dataset
    for i in range(len(df) - window_size):
        # Extract the window of data
        window = df[i:i+window_size]

        # Extract the features (X) and target (y)
        X.append(window.drop(columns=[target_column]).values)
        y.append(df[target_column][i+window_size])

    return np.array(X), np.array(y)

def run_multiple_models(train_set,val_set,cols_subset,n_epochs=100):

  window_size = 10
  target_cols = ['target_5']
  mse_val = []
  mse_train = []
  aggregated_shap = []
  for idx,cols_used in enumerate(cols_subset):
    print('-------------------------------')
    print(idx)

    X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
    X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)

    model,history = make_model(X,y, X_val, y_val, n_epochs)

    mse_val.append(min(history.history['val_loss']))
    mse_train.append(min(history.history['loss']))

    explainer = shap.DeepExplainer(model, X)
    shap_values = explainer.shap_values(X_val)

    aggregated_shap.append(np.mean(np.abs(shap_values[0]), axis=0))

    #create df
    if (idx%15 == 0):
      df = pd.DataFrame({'cols_used': cols_subset[:idx+1], 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
      df.to_csv('df_shap'+str(idx))
  df = pd.DataFrame({'cols_used': cols_subset, 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
  df.to_csv('df_shap_final')

  return df

def parse_cols_used(cols_string):
    """
    Parses the column names used in the model from the string representation.

    Args:
    cols_string (str): A string representing the tuple of column names.

    Returns:
    list: A list of column names.
    """
    # Remove the outer brackets and split the string into column names
    cols = cols_string.strip("()").split(", ")
    # Remove quotes and extra characters from column names
    cleaned_cols = [col.strip("'") for col in cols]
    return cleaned_cols

def parse_shap_values(shap_string):
    """
    Parses a string representation of a list of lists of SHAP values into a Python list of lists.

    Args:
    shap_string (str): A string representing a list of lists of SHAP values.

    Returns:
    list of lists: A list of lists of SHAP values.
    """
    # Remove the outer brackets and split the string into rows, handling newline characters
    rows = shap_string.strip('[]').split('\n')

    # Parse each row into a list of floats
    parsed_rows = [list(map(float, row.strip(' []').split())) for row in rows]

    return parsed_rows

def make_model(X, y, X_val, y_val, n_epochs, lstm_units=32,dense_units=8):
    tf.keras.backend.clear_session()

    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping and model checkpoint

    # Train the model
    history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val),
                        verbose=0)

    return model, history

def plot_mean_feature_importance(shap_values, feature_names,max_=False):
    """
    Plot the mean importance of each feature across all time steps.

    :param shap_values: A 3D array of SHAP values with shape (samples, window_size, num_features).
    :param feature_names: List of feature names.
    """
    if max_:
    # Aggregate SHAP values across all samples and time steps
      aggregated_shap = np.max(np.abs(shap_values), axis=(0))
    else:
      aggregated_shap = np.mean(np.abs(shap_values), axis=(0))


    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.bar(feature_names, aggregated_shap)
    plt.title('Mean Feature Importance Across All Time Steps')
    plt.ylabel('Mean SHAP Value')
    plt.xlabel('Features')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Zmienne

# %% [markdown]
# Newsy

# %%
train_set.columns
# Out:
# Index(['future', 'influential', 'trustworthy', 'not clickbait',
#        'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
#        'future_bart', 'future_vader', 'influential_finbert',
#        'influential_bart', 'influential_vader', 'trustworthy_finbert',
#        'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
#        'clickbait_bart', 'clickbait_vader', 'Date', 'EURUSD=X_Close',
#        'mean_future', 'mean_influential', 'mean_trustworthy', 'mean_clickbait',
#        'norm_rsi_14', 'norm_rsi_gspc_14', 'norm_slowk_14', 'norm_roc_14',
#        'log_return_1', 'log_return_5', 'log_return_10', 'log_return_20',
#        'log_return_gspc_1', 'log_return_gspc_5', 'log_return_gspc_10',
#        'log_return_gspc_20', 'target_1', 'target_5', 'target_10', 'target_20',
#        'minmax_^GSPC_Volume', 'minmax_NFLX_Volume', 'minmax_daily_variation',
#        'minmax_high_close_pressure', 'minmax_low_open_pressure',
#        'minmax_low_norm', 'minmax_close_norm', 'minmax_high_norm',
#        'minmax_open_norm'],
#       dtype='object')

# %%
plot_lagged_correlations(train_set[['norm_rsi_14', 'norm_rsi_gspc_14', 'norm_slowk_14', 'norm_roc_14',
        'minmax_^GSPC_Volume', 'minmax_NFLX_Volume', 'minmax_daily_variation',
       'minmax_high_close_pressure', 'minmax_low_open_pressure',
       'minmax_low_norm', 'minmax_close_norm', 'minmax_high_norm',
       'minmax_open_norm', 'EURUSD=X_Close', 'log_return_gspc_1' ,'log_return_gspc_5','target_1']], 'target_1')

# %%
plot_lagged_correlations(train_set[['future', 'influential', 'trustworthy', 'not clickbait',
       'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
       'future_bart', 'future_vader', 'influential_finbert',
       'influential_bart', 'influential_vader', 'trustworthy_finbert',
       'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
       'clickbait_bart', 'clickbait_vader','mean_future', 'mean_influential', 'mean_trustworthy', 'mean_clickbait','target_1']], 'target_1')

# %% [markdown]
# ### Shap dla prostych LSTM - szukanie globalnej wagi kolumn

# %%
cols = ['finbert_Score', 'bart_Score', 'vader_Score',
        'mean_future', 'mean_influential', 'mean_trustworthy', 'mean_clickbait',
        'norm_rsi_14', 'norm_rsi_gspc_14',
        'norm_slowk_14', 'norm_roc_14',
        'minmax_NFLX_Volume','log_return_5','log_return_1','EURUSD=X_Close',
        'minmax_daily_variation', 'minmax_high_close_pressure',
        'minmax_low_open_pressure','minmax_NFLX_Volume',
        'minmax_low_norm', 'minmax_close_norm',
        'minmax_high_norm', 'minmax_open_norm']

u = create_unique_subsets(cols, subset_size=5, min_diff=3)

# %%
shift_ = 5
window_size = 10
target_cols = ['target_5']
y_base_val = val_set[target_cols[0]].shift(shift_)[window_size:].values
y_base_train = train_set[target_cols[0]].shift(shift_)[window_size:].values
y_base0_val = [0 for i in range((val_set.shape[0]-window_size))]
y_base0_train = [0 for i in range((train_set.shape[0]-window_size))]

# %%
len(u)
# Out:
# 97

# %%
df = run_multiple_models(train_set,val_set,u,n_epochs=200)
# Out:
# -------------------------------
# 0
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 1
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 2
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 3
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 4
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 5
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 6
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 7
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 8
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 9
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 10
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 11
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 12
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 13
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 14
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 15
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 16
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 17
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 18
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 19
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 20
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 21
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 22
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 23
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 24
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 25
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 26
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 27
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 28
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 29
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 30
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 31
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 32
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 33
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 34
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 35
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 36
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 37
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 38
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 39
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 40
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 41
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 42
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 43
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 44
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 45
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 46
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 47
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 48
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 49
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 50
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 51
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 52
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 53
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 54
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 55
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 56
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 57
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 58
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 59
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 60
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 61
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 62
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 63
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 64
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 65
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 66
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 67
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 68
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 69
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 70
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 71
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 72
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 73
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 74
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 75
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 76
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 77
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 78
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 79
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 80
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 81
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 82
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 83
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 84
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 85
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 86
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 87
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 88
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 89
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 90
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 91
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 92
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 93
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 94
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 95
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 96
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
df = pd.read_csv("df_shap_final")
df['cols_used'] = df['cols_used'].apply(parse_cols_used)
df['aggregated_shap'] = df['aggregated_shap'].apply(parse_shap_values)

top_10_df = df.nsmallest(10, 'mse_val')

# %%
column_importance_sum_count = {}

for index, row in top_10_df.iterrows():
    shap_values = row['aggregated_shap']
    cols = row['cols_used']
    mean_shap = np.mean(shap_values, axis=0)

    # Update the sum and count of mean SHAP values for each column
    for col, value in zip(cols, mean_shap):
        if col in column_importance_sum_count:
            column_importance_sum_count[col]['sum'] += value
            column_importance_sum_count[col]['count'] += 1
        else:
            column_importance_sum_count[col] = {'sum': value, 'count': 1}

# Calculate the mean importance for each column
column_importance_mean = {col: (val['sum'] / val['count'] , val['count']) for col, val in column_importance_sum_count.items()}

# Sort the column importance dictionary for better readability
sorted_column_importance_mean = dict(sorted(column_importance_mean.items(), key=lambda item: item[1], reverse=True))

sorted_column_importance_mean
# Out:
# {'norm_slowk_14': (0.0031622160000000002, 1),
#  'finbert_Score': (0.0030838123333333336, 3),
#  'norm_rsi_gspc_14': (0.002682083, 8),
#  'vader_Score': (0.002496601666666667, 3),
#  'norm_roc_14': (0.002047493, 1),
#  'mean_influential': (0.0020194784999999996, 2),
#  'minmax_high_norm': (0.0019710254999999997, 2),
#  'log_return_1': (0.001832732, 4),
#  'mean_trustworthy': (0.001739183, 1),
#  'norm_rsi_14': (0.001544503, 2),
#  'minmax_high_close_pressure': (0.0015380844999999998, 2),
#  'bart_Score': (0.0012428464999999999, 4),
#  'minmax_NFLX_Volume': (0.0012401130000000002, 2),
#  'log_return_5': (0.0012082245, 2),
#  'mean_future': (0.0011291676666666667, 3),
#  'minmax_close_norm': (0.001120559, 2),
#  'minmax_daily_variation': (0.0010958079999999998, 1),
#  'mean_clickbait': (0.001065969, 3),
#  'minmax_low_open_pressure': (0.0009730890000000001, 2),
#  'minmax_low_norm': (0.000952182, 1),
#  'EURUSD=X_Close': (0.00028483100000000004, 1)}

# %% [markdown]
# ### TOP 10 modeli SHAP

# %%
#max across windows
for index, row in top_10_df.iterrows():
    print(index)
    shap_values = row['aggregated_shap']
    feature_names = row['cols_used']
    plot_mean_feature_importance(shap_values, feature_names,True)
# Out:
# 82
# 64
# 43
# 0
# 93
# 7
# 30
# 94
# 25
# 27

# %%
#mean across windows
for index, row in top_10_df.iterrows():
    print(index)
    shap_values = row['aggregated_shap']
    feature_names = row['cols_used']
    plot_mean_feature_importance(shap_values, feature_names)
# Out:
# 82
# 64
# 43
# 0
# 30
# 94
# 25
# 27

# %% [markdown]
# ### Przykładowy model

# %%
window_size = 10
target_cols = ['target_5']
cols_used = {'finbert_Score',
 'bart_Score',
 'vader_Score',
 'mean_future',
 'mean_influential'}
X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)

#model,history = make_model(X,y,100,lstm_units=32)
model, history = make_model_better(X, y, X_val, y_val, n_epochs=200, lstm_units=32,
                              dense_units=8, patience=100)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Train on 646 samples, validate on 30 samples
# Epoch 1/200
# 646/646 [==============================] - 2s 4ms/sample - loss: 0.0090 - val_loss: 0.0021
# Epoch 2/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0060 - val_loss: 0.0032
# Epoch 3/200
# 646/646 [==============================] - 0s 440us/sample - loss: 0.0070 - val_loss: 0.0017
# Epoch 4/200
# 646/646 [==============================] - 0s 457us/sample - loss: 0.0063 - val_loss: 0.0013
# Epoch 5/200
# 646/646 [==============================] - 0s 423us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 6/200
# 646/646 [==============================] - 0s 409us/sample - loss: 0.0059 - val_loss: 0.0014
# Epoch 7/200
# 646/646 [==============================] - 0s 420us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 8/200
# 646/646 [==============================] - 0s 444us/sample - loss: 0.0060 - val_loss: 0.0013
# Epoch 9/200
# 646/646 [==============================] - 0s 404us/sample - loss: 0.0060 - val_loss: 0.0014
# Epoch 10/200
# 646/646 [==============================] - 0s 410us/sample - loss: 0.0059 - val_loss: 0.0017
# Epoch 11/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0059 - val_loss: 0.0019
# Epoch 12/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0059 - val_loss: 0.0014
# Epoch 13/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 14/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0062 - val_loss: 0.0014
# Epoch 15/200
# 646/646 [==============================] - 0s 424us/sample - loss: 0.0059 - val_loss: 0.0018
# Epoch 16/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0061 - val_loss: 0.0015
# Epoch 17/200
# 646/646 [==============================] - 0s 490us/sample - loss: 0.0059 - val_loss: 0.0017
# Epoch 18/200
# 646/646 [==============================] - 0s 562us/sample - loss: 0.0059 - val_loss: 0.0022
# Epoch 19/200
# 646/646 [==============================] - 0s 513us/sample - loss: 0.0059 - val_loss: 0.0018
# Epoch 20/200
# 646/646 [==============================] - 0s 544us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 21/200
# 646/646 [==============================] - 0s 543us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 22/200
# 646/646 [==============================] - 0s 530us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 23/200
# 646/646 [==============================] - 0s 540us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 24/200
# 646/646 [==============================] - 0s 573us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 25/200
# 646/646 [==============================] - 0s 554us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 26/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0059 - val_loss: 0.0016
# Epoch 27/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0059 - val_loss: 0.0017
# Epoch 28/200
# 646/646 [==============================] - 0s 423us/sample - loss: 0.0059 - val_loss: 0.0016
# Epoch 29/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 30/200
# 646/646 [==============================] - 0s 413us/sample - loss: 0.0058 - val_loss: 0.0016
# Epoch 31/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0058 - val_loss: 0.0017
# Epoch 32/200
# 646/646 [==============================] - 0s 426us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 33/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 34/200
# 646/646 [==============================] - 0s 434us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 35/200
# 646/646 [==============================] - 0s 402us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 36/200
# 646/646 [==============================] - 0s 422us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 37/200
# 646/646 [==============================] - 0s 417us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 38/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0061 - val_loss: 0.0016
# Epoch 39/200
# 646/646 [==============================] - 0s 423us/sample - loss: 0.0058 - val_loss: 0.0017
# Epoch 40/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0059 - val_loss: 0.0014
# Epoch 41/200
# 646/646 [==============================] - 0s 419us/sample - loss: 0.0058 - val_loss: 0.0015
# Epoch 42/200
# 646/646 [==============================] - 0s 404us/sample - loss: 0.0058 - val_loss: 0.0014
# Epoch 43/200
# 646/646 [==============================] - 0s 419us/sample - loss: 0.0058 - val_loss: 0.0015
# Epoch 44/200
# 646/646 [==============================] - 0s 414us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 45/200
# 646/646 [==============================] - 0s 410us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 46/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0058 - val_loss: 0.0018
# Epoch 47/200
# 646/646 [==============================] - 0s 431us/sample - loss: 0.0058 - val_loss: 0.0021
# Epoch 48/200
# 646/646 [==============================] - 0s 435us/sample - loss: 0.0062 - val_loss: 0.0016
# Epoch 49/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0058 - val_loss: 0.0014
# Epoch 50/200
# 646/646 [==============================] - 0s 410us/sample - loss: 0.0059 - val_loss: 0.0017
# Epoch 51/200
# 646/646 [==============================] - 0s 430us/sample - loss: 0.0058 - val_loss: 0.0020
# Epoch 52/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0059 - val_loss: 0.0016
# Epoch 53/200
# 646/646 [==============================] - 0s 404us/sample - loss: 0.0058 - val_loss: 0.0015
# Epoch 54/200
# 646/646 [==============================] - 0s 425us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 55/200
# 646/646 [==============================] - 0s 452us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 56/200
# 646/646 [==============================] - 0s 411us/sample - loss: 0.0059 - val_loss: 0.0014
# Epoch 57/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0057 - val_loss: 0.0017
# Epoch 58/200
# 646/646 [==============================] - 0s 424us/sample - loss: 0.0058 - val_loss: 0.0013
# Epoch 59/200
# 646/646 [==============================] - 0s 407us/sample - loss: 0.0058 - val_loss: 0.0017
# Epoch 60/200
# 646/646 [==============================] - 0s 404us/sample - loss: 0.0058 - val_loss: 0.0015
# Epoch 61/200
# 646/646 [==============================] - 0s 402us/sample - loss: 0.0057 - val_loss: 0.0017
# Epoch 62/200
# 646/646 [==============================] - 0s 421us/sample - loss: 0.0057 - val_loss: 0.0014
# Epoch 63/200
# 646/646 [==============================] - 0s 563us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 64/200
# 646/646 [==============================] - 0s 533us/sample - loss: 0.0059 - val_loss: 0.0015
# Epoch 65/200
# 646/646 [==============================] - 0s 607us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 66/200
# 646/646 [==============================] - 0s 539us/sample - loss: 0.0057 - val_loss: 0.0015
# Epoch 67/200
# 646/646 [==============================] - 0s 515us/sample - loss: 0.0057 - val_loss: 0.0017
# Epoch 68/200
# 646/646 [==============================] - 0s 546us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 69/200
# 646/646 [==============================] - 0s 530us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 70/200
# 646/646 [==============================] - 0s 568us/sample - loss: 0.0057 - val_loss: 0.0014
# Epoch 71/200
# 646/646 [==============================] - 0s 532us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 72/200
# 646/646 [==============================] - 0s 423us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 73/200
# 646/646 [==============================] - 0s 475us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 74/200
# 646/646 [==============================] - 1s 782us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 75/200
# 646/646 [==============================] - 0s 478us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 76/200
# 646/646 [==============================] - 1s 954us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 77/200
# 646/646 [==============================] - 1s 815us/sample - loss: 0.0057 - val_loss: 0.0014
# Epoch 78/200
# 646/646 [==============================] - 1s 852us/sample - loss: 0.0059 - val_loss: 0.0013
# Epoch 79/200
# 646/646 [==============================] - 1s 1ms/sample - loss: 0.0057 - val_loss: 0.0017
# Epoch 80/200
# 646/646 [==============================] - 0s 689us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 81/200
# 646/646 [==============================] - 0s 684us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 82/200
# 646/646 [==============================] - 1s 1ms/sample - loss: 0.0056 - val_loss: 0.0015
# Epoch 83/200
# 646/646 [==============================] - 1s 1ms/sample - loss: 0.0057 - val_loss: 0.0014
# Epoch 84/200
# 646/646 [==============================] - 1s 800us/sample - loss: 0.0059 - val_loss: 0.0012
# Epoch 85/200
# 646/646 [==============================] - 0s 672us/sample - loss: 0.0058 - val_loss: 0.0012
# Epoch 86/200
# 646/646 [==============================] - 0s 662us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 87/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0057 - val_loss: 0.0015
# Epoch 88/200
# 646/646 [==============================] - 0s 588us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 89/200
# 646/646 [==============================] - 0s 771us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 90/200
# 646/646 [==============================] - 1s 986us/sample - loss: 0.0056 - val_loss: 0.0015
# Epoch 91/200
# 646/646 [==============================] - 0s 720us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 92/200
# 646/646 [==============================] - 1s 875us/sample - loss: 0.0056 - val_loss: 0.0016
# Epoch 93/200
# 646/646 [==============================] - 0s 554us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 94/200
# 646/646 [==============================] - 0s 543us/sample - loss: 0.0057 - val_loss: 0.0012
# Epoch 95/200
# 646/646 [==============================] - 0s 547us/sample - loss: 0.0058 - val_loss: 0.0012
# Epoch 96/200
# 646/646 [==============================] - 0s 543us/sample - loss: 0.0056 - val_loss: 0.0017
# Epoch 97/200
# 646/646 [==============================] - 0s 534us/sample - loss: 0.0057 - val_loss: 0.0012
# Epoch 98/200
# 646/646 [==============================] - 0s 640us/sample - loss: 0.0058 - val_loss: 0.0012
# Epoch 99/200
# 646/646 [==============================] - 0s 550us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 100/200
# 646/646 [==============================] - 0s 460us/sample - loss: 0.0056 - val_loss: 0.0016
# Epoch 101/200
# 646/646 [==============================] - 0s 475us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 102/200
# 646/646 [==============================] - 1s 796us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 103/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 104/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0056 - val_loss: 0.0017
# Epoch 105/200
# 646/646 [==============================] - 0s 416us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 106/200
# 646/646 [==============================] - 0s 601us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 107/200
# 646/646 [==============================] - 0s 635us/sample - loss: 0.0058 - val_loss: 0.0012
# Epoch 108/200
# 646/646 [==============================] - 0s 679us/sample - loss: 0.0057 - val_loss: 0.0016
# Epoch 109/200
# 646/646 [==============================] - 0s 518us/sample - loss: 0.0056 - val_loss: 0.0016
# Epoch 110/200
# 646/646 [==============================] - 0s 687us/sample - loss: 0.0057 - val_loss: 0.0013
# Epoch 111/200
# 646/646 [==============================] - 0s 684us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 112/200
# 646/646 [==============================] - 0s 544us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 113/200
# 646/646 [==============================] - 0s 630us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 114/200
# 646/646 [==============================] - 1s 813us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 115/200
# 646/646 [==============================] - 1s 1ms/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 116/200
# 646/646 [==============================] - 0s 606us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 117/200
# 646/646 [==============================] - 0s 745us/sample - loss: 0.0055 - val_loss: 0.0015
# Epoch 118/200
# 646/646 [==============================] - 0s 685us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 119/200
# 646/646 [==============================] - 0s 712us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 120/200
# 646/646 [==============================] - 0s 507us/sample - loss: 0.0056 - val_loss: 0.0018
# Epoch 121/200
# 646/646 [==============================] - 0s 431us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 122/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 123/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0056 - val_loss: 0.0014
# Epoch 124/200
# 646/646 [==============================] - 0s 413us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 125/200
# 646/646 [==============================] - 0s 442us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 126/200
# 646/646 [==============================] - 0s 444us/sample - loss: 0.0055 - val_loss: 0.0012
# Epoch 127/200
# 646/646 [==============================] - 0s 545us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 128/200
# 646/646 [==============================] - 0s 576us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 129/200
# 646/646 [==============================] - 0s 619us/sample - loss: 0.0056 - val_loss: 0.0010
# Epoch 130/200
# 646/646 [==============================] - 0s 523us/sample - loss: 0.0057 - val_loss: 0.0012
# Epoch 131/200
# 646/646 [==============================] - 0s 576us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 132/200
# 646/646 [==============================] - 0s 543us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 133/200
# 646/646 [==============================] - 0s 564us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 134/200
# 646/646 [==============================] - 0s 590us/sample - loss: 0.0055 - val_loss: 0.0011
# Epoch 135/200
# 646/646 [==============================] - 0s 414us/sample - loss: 0.0056 - val_loss: 0.0011
# Epoch 136/200
# 646/646 [==============================] - 0s 406us/sample - loss: 0.0056 - val_loss: 0.0013
# Epoch 137/200
# 646/646 [==============================] - 0s 430us/sample - loss: 0.0055 - val_loss: 0.0012
# Epoch 138/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0056 - val_loss: 0.0010
# Epoch 139/200
# 646/646 [==============================] - 0s 402us/sample - loss: 0.0056 - val_loss: 0.0015
# Epoch 140/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0055 - val_loss: 0.0014
# Epoch 141/200
# 646/646 [==============================] - 0s 488us/sample - loss: 0.0056 - val_loss: 9.8236e-04
# Epoch 142/200
# 646/646 [==============================] - 0s 410us/sample - loss: 0.0056 - val_loss: 0.0011
# Epoch 143/200
# 646/646 [==============================] - 0s 416us/sample - loss: 0.0055 - val_loss: 0.0013
# Epoch 144/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 145/200
# 646/646 [==============================] - 0s 410us/sample - loss: 0.0056 - val_loss: 0.0012
# Epoch 146/200
# 646/646 [==============================] - 0s 407us/sample - loss: 0.0055 - val_loss: 0.0013
# Epoch 147/200
# 646/646 [==============================] - 0s 413us/sample - loss: 0.0055 - val_loss: 0.0012
# Epoch 148/200
# 646/646 [==============================] - 0s 426us/sample - loss: 0.0055 - val_loss: 0.0013
# Epoch 149/200
# 646/646 [==============================] - 0s 423us/sample - loss: 0.0056 - val_loss: 0.0010
# Epoch 150/200
# 646/646 [==============================] - 0s 407us/sample - loss: 0.0056 - val_loss: 0.0011
# Epoch 151/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0057 - val_loss: 0.0011
# Epoch 152/200
# 646/646 [==============================] - 0s 432us/sample - loss: 0.0055 - val_loss: 0.0013
# Epoch 153/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0055 - val_loss: 0.0010
# Epoch 154/200
# 646/646 [==============================] - 0s 445us/sample - loss: 0.0055 - val_loss: 9.4695e-04
# Epoch 155/200
# 646/646 [==============================] - 0s 427us/sample - loss: 0.0055 - val_loss: 0.0012
# Epoch 156/200
# 646/646 [==============================] - 0s 467us/sample - loss: 0.0055 - val_loss: 8.5448e-04
# Epoch 157/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0055 - val_loss: 0.0012
# Epoch 158/200
# 646/646 [==============================] - 0s 413us/sample - loss: 0.0055 - val_loss: 0.0014
# Epoch 159/200
# 646/646 [==============================] - 0s 422us/sample - loss: 0.0055 - val_loss: 0.0012
# Epoch 160/200
# 646/646 [==============================] - 0s 432us/sample - loss: 0.0054 - val_loss: 0.0011
# Epoch 161/200
# 646/646 [==============================] - 0s 409us/sample - loss: 0.0055 - val_loss: 0.0013
# Epoch 162/200
# 646/646 [==============================] - 0s 423us/sample - loss: 0.0054 - val_loss: 0.0012
# Epoch 163/200
# 646/646 [==============================] - 0s 413us/sample - loss: 0.0054 - val_loss: 0.0011
# Epoch 164/200
# 646/646 [==============================] - 0s 422us/sample - loss: 0.0055 - val_loss: 0.0016
# Epoch 165/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0054 - val_loss: 9.9371e-04
# Epoch 166/200
# 646/646 [==============================] - 0s 440us/sample - loss: 0.0054 - val_loss: 0.0012
# Epoch 167/200
# 646/646 [==============================] - 0s 436us/sample - loss: 0.0054 - val_loss: 9.8058e-04
# Epoch 168/200
# 646/646 [==============================] - 0s 441us/sample - loss: 0.0054 - val_loss: 7.4683e-04
# Epoch 169/200
# 646/646 [==============================] - 0s 450us/sample - loss: 0.0055 - val_loss: 0.0010
# Epoch 170/200
# 646/646 [==============================] - 0s 455us/sample - loss: 0.0055 - val_loss: 6.6963e-04
# Epoch 171/200
# 646/646 [==============================] - 0s 552us/sample - loss: 0.0055 - val_loss: 0.0010
# Epoch 172/200
# 646/646 [==============================] - 0s 526us/sample - loss: 0.0054 - val_loss: 0.0012
# Epoch 173/200
# 646/646 [==============================] - 0s 535us/sample - loss: 0.0053 - val_loss: 9.6075e-04
# Epoch 174/200
# 646/646 [==============================] - 0s 529us/sample - loss: 0.0054 - val_loss: 8.5349e-04
# Epoch 175/200
# 646/646 [==============================] - 0s 555us/sample - loss: 0.0054 - val_loss: 0.0012
# Epoch 176/200
# 646/646 [==============================] - 0s 626us/sample - loss: 0.0053 - val_loss: 6.1969e-04
# Epoch 177/200
# 646/646 [==============================] - 0s 557us/sample - loss: 0.0053 - val_loss: 0.0011
# Epoch 178/200
# 646/646 [==============================] - 0s 566us/sample - loss: 0.0052 - val_loss: 6.3252e-04
# Epoch 179/200
# 646/646 [==============================] - 0s 539us/sample - loss: 0.0054 - val_loss: 0.0010
# Epoch 180/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0055 - val_loss: 0.0011
# Epoch 181/200
# 646/646 [==============================] - 0s 417us/sample - loss: 0.0054 - val_loss: 7.8111e-04
# Epoch 182/200
# 646/646 [==============================] - 0s 419us/sample - loss: 0.0053 - val_loss: 6.3880e-04
# Epoch 183/200
# 646/646 [==============================] - 0s 437us/sample - loss: 0.0053 - val_loss: 0.0012
# Epoch 184/200
# 646/646 [==============================] - 0s 411us/sample - loss: 0.0053 - val_loss: 0.0011
# Epoch 185/200
# 646/646 [==============================] - 0s 446us/sample - loss: 0.0052 - val_loss: 5.9087e-04
# Epoch 186/200
# 646/646 [==============================] - 0s 407us/sample - loss: 0.0053 - val_loss: 7.1019e-04
# Epoch 187/200
# 646/646 [==============================] - 0s 448us/sample - loss: 0.0053 - val_loss: 9.9251e-04
# Epoch 188/200
# 646/646 [==============================] - 0s 452us/sample - loss: 0.0051 - val_loss: 6.0526e-04
# Epoch 189/200
# 646/646 [==============================] - 0s 469us/sample - loss: 0.0052 - val_loss: 0.0013
# Epoch 190/200
# 646/646 [==============================] - 0s 435us/sample - loss: 0.0053 - val_loss: 8.2030e-04
# Epoch 191/200
# 646/646 [==============================] - 0s 407us/sample - loss: 0.0050 - val_loss: 7.9331e-04
# Epoch 192/200
# 646/646 [==============================] - 0s 417us/sample - loss: 0.0049 - val_loss: 0.0012
# Epoch 193/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0051 - val_loss: 7.9694e-04
# Epoch 194/200
# 646/646 [==============================] - 0s 425us/sample - loss: 0.0051 - val_loss: 8.0511e-04
# Epoch 195/200
# 646/646 [==============================] - 0s 417us/sample - loss: 0.0049 - val_loss: 8.9077e-04
# Epoch 196/200
# 646/646 [==============================] - 0s 424us/sample - loss: 0.0048 - val_loss: 6.6810e-04
# Epoch 197/200
# 646/646 [==============================] - 0s 411us/sample - loss: 0.0048 - val_loss: 6.6595e-04
# Epoch 198/200
# 646/646 [==============================] - 0s 439us/sample - loss: 0.0050 - val_loss: 7.8154e-04
# Epoch 199/200
# 646/646 [==============================] - 0s 416us/sample - loss: 0.0054 - val_loss: 0.0012
# Epoch 200/200
# 646/646 [==============================] - 0s 457us/sample - loss: 0.0049 - val_loss: 8.1967e-04

# %% [markdown]
# #### wyniki

# %%
model = load_model('best_model.h5')

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)

# %%
k=-60
plot_actual_vs_predicted(y[k:], y_pred_train[k:], y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val, y_base0_val)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, np.array([1]), np.array([1]), y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, np.array([1]), np.array([1]), y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, np.array([1]), np.array([1]), y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.046457  0.005140  0.071691  0.129518  271.548263  1.543570
# Test        0.000000  0.000000  0.000000       NaN    0.000000  0.000000
# Validation  0.020457  0.000591  0.024308  0.424287  206.240505  0.679702
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.048982  0.005906  0.076853 -0.000329  100.0  1.627464
# Test        0.000000  0.000000  0.000000       NaN    0.0  0.000000
# Validation  0.028025  0.001089  0.032995 -0.060713  100.0  0.931150
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score        MAPE      MASE
# Train       0.074259  0.011990  0.109500 -1.030736  634.540522  2.467319
# Test        0.000000  0.000000  0.000000       NaN    0.000000  0.000000
# Validation  0.045731  0.003208  0.056637 -2.125460  418.216884  1.519465

# %%
explainer = shap.DeepExplainer(model, X)
shap_values = explainer.shap_values(X_val)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_feature_importance(shap_values, feature_names,window_size):
    """
    Plot the importance of each feature at each step in the window.

    :param shap_values: A 3D array of SHAP values with shape (samples, window_size, num_features).
    :param feature_names: List of feature names.
    """
    # Aggregate SHAP values across all samples
    aggregated_shap = np.mean(np.abs(shap_values[0]), axis=0)

    # Create a plot for each time step in the window
    window_size = aggregated_shap.shape[0]
    num_features = aggregated_shap.shape[1]

    # Set up the plot
    fig, axs = plt.subplots(window_size, 1, figsize=(10, window_size * 2))
    fig.suptitle('Feature Importance in Each Window Step')

    # Plot each time step
    for i in range(window_size):
        axs[i].bar(feature_names, aggregated_shap[i, :])
        axs[i].set_title(f'Time Step {i+1}')
        axs[i].set_ylabel('SHAP Value')
        axs[i].set_xlabel('Features')

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# Example usage
feature_names = list(cols_used)
plot_feature_importance(shap_values, feature_names,window_size)
