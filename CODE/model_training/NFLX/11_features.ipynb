# %% [markdown]
# ### Importy

# %%
import os
os.chdir('d:/Projekty/LBN-INZ/CODE/model_training/')
print(os.getcwd())
# Out:
# d:\Projekty\LBN-INZ\CODE\model_training

# %%
import pandas as pd
import numpy as np
from scripts.essentials import *
from scripts.plots import *
from scripts.train_utilities import *

# %%
cols_news = ['future', 'influential', 'trustworthy', 'not clickbait',
       'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
       'future_bart', 'future_vader', 'influential_finbert',
       'influential_bart', 'influential_vader', 'trustworthy_finbert',
       'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
       'clickbait_bart', 'clickbait_vader',
       'mean_future','mean_influential', 'mean_trustworthy', 'mean_clickbait' 
         ]

# %% [markdown]
# ### Połączenie News + FE

# %%
prefix = "NFLX"
df_news_path = "NFLX_full_agg_8.csv"

# %%
df_news = pd.read_csv("csv/"+prefix+"/"+df_news_path)
df_finance = pd.read_csv("csv/finance_all.csv")

# %% [markdown]
# połączenie z newsami + uzupełnienie braków

# %%
df_m = create_merged_df(df_finance, df_news, prefix)

# %% [markdown]
# dorobienie ramki bez weekendu

# %%
df_with_weekends = df_m.copy()
df_without_weekends = df_m.copy()

df_without_weekends = apply_weighted_weekend_news(df_without_weekends,'Date', cols_news, weights=[0.6,0.2,0.2])

# %% [markdown]
# wyliczenie cech

# %%
df_without_weekends = calculate_technical_indicators(df_without_weekends,'Date',prefix+'_Open',prefix+ '_High',prefix+ '_Low',
    prefix+'_Close',prefix+ '_Volume','^GSPC_Close')
df_with_weekends = calculate_technical_indicators(df_with_weekends,'Date',prefix+'_Open',prefix+ '_High',prefix+ '_Low',
    prefix+'_Close',prefix+ '_Volume','^GSPC_Close',True)

# %%
df_without_weekends.describe()
# Out:
#            future  influential  trustworthy  not clickbait  finbert_Score  \
# count  844.000000   844.000000   844.000000     844.000000     844.000000
# mean     0.307639     0.859943     0.749651       0.279758      -0.018189
# min      0.000000     0.000000     0.000000       0.000000      -0.857271
# 25%      0.300991     0.955788     0.788186       0.272909      -0.147315
# 50%      0.343211     0.968809     0.836816       0.308538       0.000000
# 75%      0.372041     0.974955     0.873308       0.337757       0.113103
# max      0.466300     0.996581     0.996807       0.448209       0.893353
# std      0.114261     0.297782     0.263147       0.104524       0.227252
#
#        bart_Score  vader_Score  future_finbert  future_bart  future_vader  \
# count  844.000000   844.000000      844.000000   844.000000    844.000000
# mean     0.536044     0.257049       -0.006222     0.183585      0.088333
# min      0.000000    -0.648600       -0.309736     0.000000     -0.241770
# 25%      0.487362     0.088951       -0.050171     0.155969      0.026874
# 50%      0.579987     0.265040        0.000000     0.196920      0.089535
# 75%      0.667751     0.414083        0.041678     0.233299      0.146384
# max      0.988771     0.861067        0.257228     0.397967      0.292486
# std      0.217349     0.215665        0.080432     0.079473      0.075749
#
#        ...  log_return_gspc_5  log_return_gspc_10  log_return_gspc_20  \
# count  ...         839.000000          834.000000          824.000000
# mean   ...           0.001595            0.003340            0.006568
# min    ...          -0.107802           -0.130239           -0.129153
# 25%    ...          -0.011387           -0.014255           -0.021634
# 50%    ...           0.003315            0.007088            0.014519
# 75%    ...           0.016252            0.024355            0.037275
# max    ...           0.070679            0.092059            0.114863
# std    ...           0.023981            0.032718            0.043661
#
#        daily_variation  high_close_pressure  low_open_pressure    low_norm  \
# count       844.000000           844.000000         844.000000  844.000000
# mean          0.032774             0.016069          -0.016307    0.985178
# min           0.007246             0.000000          -0.133320    0.773796
# 25%           0.020838             0.005178          -0.022436    0.954536
# 50%           0.028268             0.012520          -0.013038    0.986037
# 75%           0.040057             0.022652          -0.006160    1.019091
# max           0.147594             0.091803           0.000000    1.134243
# std           0.016739             0.014142           0.014006    0.050563
#
#        close_norm   high_norm   open_norm
# count  844.000000  844.000000  844.000000
# mean     1.001799    1.017799    1.001409
# min      0.793773    0.842821    0.816802
# 25%      0.969595    0.988395    0.972933
# 50%      1.002599    1.016085    1.001247
# 75%      1.038039    1.050769    1.032998
# max      1.168080    1.191404    1.159548
# std      0.052094    0.048974    0.047636
#
# [8 rows x 52 columns]

# %%
df_with_weekends.to_csv("csv/"+prefix+"/"+prefix+"_with_weekends.csv", index=False)
df_without_weekends.to_csv("csv/"+prefix+"/"+prefix+"_without_weekends.csv", index=False)

# %%
df_without_weekends.columns
# Out:
# Index(['future', 'influential', 'trustworthy', 'not clickbait',
#        'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
#        'future_bart', 'future_vader', 'influential_finbert',
#        'influential_bart', 'influential_vader', 'trustworthy_finbert',
#        'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
#        'clickbait_bart', 'clickbait_vader', 'Date', '^GSPC_Close',
#        '^GSPC_Volume', 'EURUSD=X_Close', 'NFLX_Open', 'NFLX_High', 'NFLX_Low',
#        'NFLX_Close', 'NFLX_Volume', 'mean_future', 'mean_influential',
#        'mean_trustworthy', 'mean_clickbait', 'norm_rsi_14', 'norm_rsi_gspc_14',
#        'norm_slowk_14', 'vwap_14', 'norm_roc_14', 'log_return_1',
#        'log_return_5', 'log_return_10', 'log_return_20', 'log_return_gspc_1',
#        'log_return_gspc_5', 'log_return_gspc_10', 'log_return_gspc_20',
#        'daily_variation', 'high_close_pressure', 'low_open_pressure',
#        'low_norm', 'close_norm', 'high_norm', 'open_norm'],
#       dtype='object')

# %%
close_price_statistics_by_year(df_without_weekends, 'Date', prefix+'_Close')
# Out:
#    Year         Min         Max        Mean        Std  Percentile_25  \
# 0  2020  469.959991  556.549988  504.183635  22.480649     485.172508
# 1  2021  484.980011  691.690002  558.257508  55.792554     512.400024
# 2  2022  166.369995  597.369995  284.868385  95.084682     216.210003
# 3  2023  292.760010  479.559998  381.517447  50.092151     335.150009
#
#    Percentile_50  Percentile_75  Mean_Abs_Diff_1D  Mean_Abs_Diff_1W  \
# 0     500.110001     522.962494          8.960689         17.753979
# 1     542.950012     599.059998          7.220880         17.091112
# 2     251.980003     351.792496          8.240770         21.034961
# 3     378.880005     428.304993          6.004341         15.760043
#
#    Mean_Abs_Diff_2W  Mean_Abs_Diff_1M  Mean_Abs_Diff_2M
# 0         25.975766         30.322499         26.401042
# 1         23.495097         33.782606         41.618392
# 2         31.478808         47.286115         87.546500
# 3         24.810212         35.954594         43.080042

# %% [markdown]
# ### Train Val Test + Normalizacja

# %%
df_without_weekends.drop(columns=[prefix+'_Open', prefix+'_High', prefix+'_Low', prefix+'_Close', '^GSPC_Close','vwap_14'], inplace=True)

# %%
df_without_weekends['target_1'] = df_without_weekends['log_return_1'].shift(-1)
df_without_weekends['target_5'] = df_without_weekends['log_return_5'].shift(-5)
df_without_weekends['target_10'] = df_without_weekends['log_return_10'].shift(-10)
df_without_weekends['target_20'] = df_without_weekends['log_return_20'].shift(-20)

# %%
train_set, val_set, test_set = split_data(df_without_weekends, 'Date', '2023-07-08', '2023-09-02', start_date_train = '2021-01-01')
print(train_set.shape)
print(val_set.shape)
print(test_set.shape)
# Out:
# (656, 50)
# (40, 50)
# (60, 50)

# %%
cols_min_max = ['^GSPC_Volume', prefix+'_Volume',
'daily_variation', 'high_close_pressure', 'low_open_pressure',
'low_norm', 'close_norm', 'high_norm', 'open_norm']

train_set, scaler_min_max = min_max_scale(train_set,'Date', cols_min_max, train_data=True, scaler=None)
val_set = min_max_scale(val_set,'Date', cols_min_max, train_data=False, scaler=scaler_min_max)
test_set = min_max_scale(test_set,'Date', cols_min_max, train_data=False, scaler=scaler_min_max)

# %%
train_set.describe().T
# Out:
#                             count                           mean  \
# future                      656.0                       0.342782
# influential                 656.0                       0.959748
# trustworthy                 656.0                       0.838646
# not clickbait               656.0                       0.312734
# finbert_Score               656.0                      -0.022149
# bart_Score                  656.0                       0.595344
# vader_Score                 656.0                       0.281704
# future_finbert              656.0                      -0.008026
# future_bart                 656.0                       0.203232
# future_vader                656.0                       0.096729
# influential_finbert         656.0                      -0.020186
# influential_bart            656.0                       0.576937
# influential_vader           656.0                       0.273388
# trustworthy_finbert         656.0                       0.003341
# trustworthy_bart            656.0                       0.502958
# trustworthy_vader           656.0                       0.256235
# clickbait_finbert           656.0                      -0.007879
# clickbait_bart              656.0                       0.184052
# clickbait_vader             656.0                       0.085897
# Date                          656  2022-04-05 07:10:14.634146304
# EURUSD=X_Close              656.0                       1.110923
# mean_future                 656.0                       0.097312
# mean_influential            656.0                       0.276713
# mean_trustworthy            656.0                       0.254178
# mean_clickbait              656.0                       0.087357
# norm_rsi_14                 656.0                       0.510235
# norm_rsi_gspc_14            656.0                       0.536486
# norm_slowk_14               656.0                       0.521768
# norm_roc_14                 656.0                       0.003707
# log_return_1                656.0                      -0.000321
# log_return_5                656.0                      -0.001338
# log_return_10               656.0                      -0.002909
# log_return_20               656.0                      -0.005526
# log_return_gspc_1           656.0                       0.000241
# log_return_gspc_5           656.0                       0.001316
# log_return_gspc_10          656.0                       0.002619
# log_return_gspc_20          656.0                        0.00525
# target_1                    656.0                      -0.000308
# target_5                    656.0                       -0.00119
# target_10                   656.0                      -0.001979
# target_20                   656.0                      -0.005497
# minmax_^GSPC_Volume         656.0                       0.329712
# minmax_NFLX_Volume          656.0                       0.045457
# minmax_daily_variation      656.0                        0.18984
# minmax_high_close_pressure  656.0                       0.179776
# minmax_low_open_pressure    656.0                       0.874353
# minmax_low_norm             656.0                        0.58488
# minmax_close_norm           656.0                       0.556019
# minmax_high_norm            656.0                       0.503449
# minmax_open_norm            656.0                       0.538203
#
#                                             min                  25%  \
# future                                      0.0             0.314979
# influential                                 0.0             0.961178
# trustworthy                                 0.0             0.809103
# not clickbait                               0.0             0.288967
# finbert_Score                         -0.857271            -0.175366
# bart_Score                                  0.0             0.523881
# vader_Score                             -0.6486             0.150631
# future_finbert                        -0.309736            -0.057078
# future_bart                                 0.0             0.169485
# future_vader                           -0.24177             0.047786
# influential_finbert                   -0.824102            -0.165125
# influential_bart                            0.0             0.508414
# influential_vader                     -0.636679             0.146035
# trustworthy_finbert                   -0.674508             -0.12302
# trustworthy_bart                            0.0             0.440121
# trustworthy_vader                     -0.450521             0.139233
# clickbait_finbert                     -0.289408            -0.054598
# clickbait_bart                              0.0              0.15151
# clickbait_vader                       -0.196315             0.040522
# Date                        2021-01-01 00:00:00  2021-08-18 18:00:00
# EURUSD=X_Close                         0.959619             1.061092
# mean_future                           -0.056561             0.067226
# mean_influential                      -0.111299             0.199702
# mean_trustworthy                      -0.083877             0.181183
# mean_clickbait                        -0.037563             0.059273
# norm_rsi_14                            0.084577             0.419302
# norm_rsi_gspc_14                       0.229686             0.452184
# norm_slowk_14                          0.000705             0.225312
# norm_roc_14                           -0.503457            -0.056623
# log_return_1                          -0.432578            -0.014159
# log_return_5                          -0.563669            -0.032423
# log_return_10                         -0.619851            -0.045105
# log_return_20                         -0.744947            -0.060372
# log_return_gspc_1                     -0.044199            -0.006108
# log_return_gspc_5                     -0.107802            -0.011306
# log_return_gspc_10                    -0.130239            -0.013978
# log_return_gspc_20                    -0.129153            -0.023746
# target_1                              -0.432578            -0.014159
# target_5                              -0.563669            -0.031831
# target_10                             -0.619851             -0.04461
# target_20                             -0.744947            -0.059126
# minmax_^GSPC_Volume                         0.0             0.263678
# minmax_NFLX_Volume                          0.0             0.017164
# minmax_daily_variation                      0.0             0.098989
# minmax_high_close_pressure                  0.0             0.058904
# minmax_low_open_pressure                    0.0             0.826111
# minmax_low_norm                             0.0              0.50523
# minmax_close_norm                           0.0             0.475871
# minmax_high_norm                            0.0             0.419089
# minmax_open_norm                            0.0             0.456583
#
#                                             50%                  75%  \
# future                                 0.348873             0.375569
# influential                            0.970313             0.975368
# trustworthy                            0.847035             0.877987
# not clickbait                          0.314047             0.341113
# finbert_Score                         -0.010054             0.127713
# bart_Score                             0.594291              0.67584
# vader_Score                            0.297627             0.427716
# future_finbert                        -0.000477              0.04952
# future_bart                            0.201648             0.237959
# future_vader                           0.100466             0.151711
# influential_finbert                   -0.009691             0.126853
# influential_bart                       0.576476             0.657286
# influential_vader                       0.29043             0.410814
# trustworthy_finbert                    0.008703             0.127093
# trustworthy_bart                       0.498418             0.567456
# trustworthy_vader                      0.265718             0.377055
# clickbait_finbert                     -0.000069             0.046072
# clickbait_bart                          0.18211             0.215043
# clickbait_vader                        0.089461             0.136034
# Date                        2022-04-05 12:00:00  2022-11-21 06:00:00
# EURUSD=X_Close                         1.100794             1.177745
# mean_future                            0.097541             0.128088
# mean_influential                       0.281258             0.357219
# mean_trustworthy                       0.255713             0.326088
# mean_clickbait                         0.086317              0.11683
# norm_rsi_14                            0.506092             0.622276
# norm_rsi_gspc_14                       0.547611             0.620208
# norm_slowk_14                          0.555124             0.809695
# norm_roc_14                            0.005968             0.074345
# log_return_1                                0.0             0.012851
# log_return_5                           0.002827              0.03623
# log_return_10                            0.0041             0.062405
# log_return_20                          0.010987             0.091671
# log_return_gspc_1                           0.0             0.007015
# log_return_gspc_5                      0.003288             0.016164
# log_return_gspc_10                     0.006821             0.023563
# log_return_gspc_20                     0.014536             0.037809
# target_1                                    0.0             0.012851
# target_5                               0.002827             0.036143
# target_10                              0.005882             0.062777
# target_20                               0.00992             0.090869
# minmax_^GSPC_Volume                    0.307298             0.372333
# minmax_NFLX_Volume                     0.031129             0.052987
# minmax_daily_variation                 0.158438             0.246572
# minmax_high_close_pressure             0.138644             0.254481
# minmax_low_open_pressure               0.899272             0.951566
# minmax_low_norm                        0.586474             0.678027
# minmax_close_norm                      0.559632             0.652582
# minmax_high_norm                       0.498025             0.597217
# minmax_open_norm                       0.538843             0.630364
#
#                                             max       std
# future                                 0.445085  0.048278
# influential                            0.996581  0.055053
# trustworthy                            0.996807  0.065947
# not clickbait                          0.448209  0.044799
# finbert_Score                          0.893353   0.24048
# bart_Score                             0.988771  0.123281
# vader_Score                             0.82608  0.207673
# future_finbert                         0.257228  0.084513
# future_bart                            0.374004  0.050766
# future_vader                           0.290075  0.072588
# influential_finbert                    0.890298  0.233827
# influential_bart                        0.98539  0.120225
# influential_vader                      0.801268  0.201058
# trustworthy_finbert                      0.8905  0.201796
# trustworthy_bart                       0.985614   0.10744
# trustworthy_vader                      0.761808  0.176038
# clickbait_finbert                       0.29443  0.081677
# clickbait_bart                         0.315942  0.046665
# clickbait_vader                        0.272111  0.068538
# Date                        2023-07-07 00:00:00       NaN
# EURUSD=X_Close                         1.234111  0.070061
# mean_future                            0.227638  0.046164
# mean_influential                       0.872382  0.127344
# mean_trustworthy                       0.872579  0.116802
# mean_clickbait                         0.246511  0.043732
# norm_rsi_14                            0.854039  0.138235
# norm_rsi_gspc_14                       0.769064  0.109312
# norm_slowk_14                          0.995344  0.313326
# norm_roc_14                            0.362079  0.117764
# log_return_1                           0.155758  0.033327
# log_return_5                           0.247582  0.076907
# log_return_10                          0.306062  0.108089
# log_return_20                          0.328298  0.162304
# log_return_gspc_1                      0.053953  0.011459
# log_return_gspc_5                      0.066752  0.024206
# log_return_gspc_10                     0.092059  0.032983
# log_return_gspc_20                     0.114863  0.045337
# target_1                               0.155758  0.033329
# target_5                               0.247582  0.076829
# target_10                              0.306062  0.108154
# target_20                              0.328298  0.162098
# minmax_^GSPC_Volume                         1.0  0.114285
# minmax_NFLX_Volume                          1.0  0.059484
# minmax_daily_variation                      1.0  0.124413
# minmax_high_close_pressure                  1.0  0.156807
# minmax_low_open_pressure                    1.0   0.10723
# minmax_low_norm                             1.0  0.145457
# minmax_close_norm                           1.0  0.144143
# minmax_high_norm                            1.0  0.145653
# minmax_open_norm                            1.0  0.143939

# %%
train_set.columns
# Out:
# Index(['future', 'influential', 'trustworthy', 'not clickbait',
#        'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
#        'future_bart', 'future_vader', 'influential_finbert',
#        'influential_bart', 'influential_vader', 'trustworthy_finbert',
#        'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
#        'clickbait_bart', 'clickbait_vader', 'Date', 'EURUSD=X_Close',
#        'mean_future', 'mean_influential', 'mean_trustworthy', 'mean_clickbait',
#        'norm_rsi_14', 'norm_rsi_gspc_14', 'norm_slowk_14', 'norm_roc_14',
#        'log_return_1', 'log_return_5', 'log_return_10', 'log_return_20',
#        'log_return_gspc_1', 'log_return_gspc_5', 'log_return_gspc_10',
#        'log_return_gspc_20', 'target_1', 'target_5', 'target_10', 'target_20',
#        'minmax_^GSPC_Volume', 'minmax_NFLX_Volume', 'minmax_daily_variation',
#        'minmax_high_close_pressure', 'minmax_low_open_pressure',
#        'minmax_low_norm', 'minmax_close_norm', 'minmax_high_norm',
#        'minmax_open_norm'],
#       dtype='object')

# %%
train_set.to_csv("csv/"+prefix+"/train_set_full.csv", index=False)
test_set.to_csv("csv/"+prefix+"/test_set_full.csv", index=False)
val_set.to_csv("csv/"+prefix+"/val_set_full.csv", index=False)

# %% [markdown]
# ### Analiza Targetu

# %%
plot_density(df_with_weekends['log_return_1'], title='Density Plot Example', xlabel='Values')

# %%
plot_density(df_without_weekends['log_return_1'], title='Density Plot Example', xlabel='Values')

# %%
plot_density(df_without_weekends['log_return_5'], title='Density Plot Example', xlabel='Values')

# %%
plot_density(df_without_weekends['log_return_10'], title='Density Plot Example', xlabel='Values')

# %%
plot_density(df_without_weekends['log_return_20'], title='Density Plot Example', xlabel='Values')
