# %% [markdown]
# ### Importy

# %%
pip install shap timeshap ta

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Conv1D, InputLayer
from keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import itertools
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import shap
from scripts.train_utilities import *
from scripts.essentials import *
from scripts.plots import *
from keras.models import load_model

# %%
tf.compat.v1.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/compat/v2_compat.py:108: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
train_set = pd.read_csv('train_set_full.csv')
test_set = pd.read_csv('test_set_full.csv')
val_set = pd.read_csv('val_set_full.csv')

# %%
prefix = "BTC-USD"

# %% [markdown]
# ### Funkcje

# %%
def create_unique_subsets(columns, subset_size=5, min_diff=2):
    """
    Create subsets of columns where each subset differs from every other subset by at least 'min_diff' columns.

    :param columns: List of all columns.
    :param subset_size: The size of each subset.
    :param min_diff: Minimum number of different columns between any two subsets.
    :return: A list of unique subsets.
    """
    all_combinations = list(itertools.combinations(columns, subset_size))
    unique_subsets = []

    for combo in all_combinations:
        if all(len(set(combo) - set(subset)) >= min_diff for subset in unique_subsets):
            unique_subsets.append(combo)

    return unique_subsets

def make_model_better(X, y, X_val, y_val, n_epochs, lstm_units=64, dense_units=10, patience=5):
    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping and model checkpoint
    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
    model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True)

    # Train the model
    history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val), callbacks=[early_stopping, model_checkpoint])

    return model, history

# Example usage:
# model, history = make_model(X_train, y_train, X_val, y_val, n_epochs=50, lstm_units=64, dense_units=10, patience=5)

def window_dataset(df, target_column, window_size):
    X = []
    y = []

    # Iterate over the dataset
    for i in range(len(df) - window_size):
        # Extract the window of data
        window = df[i:i+window_size]

        # Extract the features (X) and target (y)
        X.append(window.drop(columns=[target_column]).values)
        y.append(df[target_column][i+window_size])

    return np.array(X), np.array(y)

def run_multiple_models(train_set,val_set,cols_subset,n_epochs=100):

  window_size = 14
  target_cols = ['target_7']
  mse_val = []
  mse_train = []
  aggregated_shap = []
  for idx,cols_used in enumerate(cols_subset):
    print('-------------------------------')
    print(idx)

    X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
    X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)

    model,history = make_model(X,y, X_val, y_val, n_epochs)

    mse_val.append(min(history.history['val_loss']))
    mse_train.append(min(history.history['loss']))

    explainer = shap.DeepExplainer(model, X)
    shap_values = explainer.shap_values(X_val)

    aggregated_shap.append(np.mean(np.abs(shap_values[0]), axis=0))

    #create df
    if (idx%15 == 0):
      df = pd.DataFrame({'cols_used': cols_subset[:idx+1], 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
      df.to_csv('df_shap'+str(idx)+'.csv')
  df = pd.DataFrame({'cols_used': cols_subset, 'mse_val': mse_val, 'mse_train': mse_train,
                        'aggregated_shap':aggregated_shap})
  df.to_csv('df_shap_final.csv')

  return df

def parse_cols_used(cols_string):
    """
    Parses the column names used in the model from the string representation.

    Args:
    cols_string (str): A string representing the tuple of column names.

    Returns:
    list: A list of column names.
    """
    # Remove the outer brackets and split the string into column names
    cols = cols_string.strip("()").split(", ")
    # Remove quotes and extra characters from column names
    cleaned_cols = [col.strip("'") for col in cols]
    return cleaned_cols

def parse_shap_values(shap_string):
    """
    Parses a string representation of a list of lists of SHAP values into a Python list of lists.

    Args:
    shap_string (str): A string representing a list of lists of SHAP values.

    Returns:
    list of lists: A list of lists of SHAP values.
    """
    # Remove the outer brackets and split the string into rows, handling newline characters
    rows = shap_string.strip('[]').split('\n')

    # Parse each row into a list of floats
    parsed_rows = [list(map(float, row.strip(' []').split())) for row in rows]

    return parsed_rows

def make_model(X, y, X_val, y_val, n_epochs, lstm_units=32,dense_units=8):
    tf.keras.backend.clear_session()

    model = Sequential()
    model.add(InputLayer(input_shape=(X.shape[1], X.shape[2])))

    # LSTM layers
    model.add(LSTM(units=lstm_units, return_sequences=True))
    model.add(LSTM(units=lstm_units, return_sequences=False))

    # Dense layers
    model.add(Dense(units=dense_units))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Early stopping and model checkpoint

    # Train the model
    history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val),
                        verbose=0)

    return model, history

def plot_mean_feature_importance(shap_values, feature_names,max_=False):
    """
    Plot the mean importance of each feature across all time steps.

    :param shap_values: A 3D array of SHAP values with shape (samples, window_size, num_features).
    :param feature_names: List of feature names.
    """
    if max_:
    # Aggregate SHAP values across all samples and time steps
      aggregated_shap = np.max(np.abs(shap_values), axis=(0))
    else:
      aggregated_shap = np.mean(np.abs(shap_values), axis=(0))


    # Create the plot
    plt.figure(figsize=(10, 6))
    plt.bar(feature_names, aggregated_shap)
    plt.title('Mean Feature Importance Across All Time Steps')
    plt.ylabel('Mean SHAP Value')
    plt.xlabel('Features')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Zmienne

# %% [markdown]
# Newsy

# %%
train_set.columns
# Out:
# Index(['future', 'influential', 'trustworthy', 'not clickbait',
#        'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
#        'future_bart', 'future_vader', 'influential_finbert',
#        'influential_bart', 'influential_vader', 'trustworthy_finbert',
#        'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
#        'clickbait_bart', 'clickbait_vader', 'Date', '^GSPC_Close',
#        'EURUSD=X_Close', 'BTC-USD_Open', 'BTC-USD_High', 'BTC-USD_Low',
#        'BTC-USD_Close', 'mean_future', 'mean_influential', 'mean_trustworthy',
#        'mean_clickbait', 'norm_rsi_14', 'norm_rsi_gspc_14', 'norm_slowk_14',
#        'vwap_14', 'norm_roc_14', 'log_return_1', 'log_return_7',
#        'log_return_14', 'log_return_28', 'log_return_gspc_1',
#        'log_return_gspc_7', 'log_return_gspc_14', 'log_return_gspc_28',
#        'target_1', 'target_7', 'target_14', 'target_28', 'minmax_^GSPC_Volume',
#        'minmax_BTC-USD_Volume', 'minmax_daily_variation',
#        'minmax_high_close_pressure', 'minmax_low_open_pressure',
#        'minmax_low_norm', 'minmax_close_norm', 'minmax_high_norm',
#        'minmax_open_norm'],
#       dtype='object')

# %%
plot_lagged_correlations(train_set[['norm_rsi_14', 'norm_rsi_gspc_14', 'norm_slowk_14', 'norm_roc_14',
        'minmax_^GSPC_Volume', 'minmax_BTC-USD_Volume', 'minmax_daily_variation',
       'minmax_high_close_pressure', 'minmax_low_open_pressure',
       'minmax_low_norm', 'minmax_close_norm', 'minmax_high_norm',
       'minmax_open_norm', 'EURUSD=X_Close', 'log_return_gspc_1' ,'log_return_gspc_7','target_7']], 'target_7')

# %%
plot_lagged_correlations(train_set[['future', 'influential', 'trustworthy', 'not clickbait',
       'finbert_Score', 'bart_Score', 'vader_Score', 'future_finbert',
       'future_bart', 'future_vader', 'influential_finbert',
       'influential_bart', 'influential_vader', 'trustworthy_finbert',
       'trustworthy_bart', 'trustworthy_vader', 'clickbait_finbert',
       'clickbait_bart', 'clickbait_vader','mean_future', 'mean_influential', 'mean_trustworthy', 'mean_clickbait','target_7']], 'target_7')

# %% [markdown]
# ### Shap dla prostych LSTM - szukanie globalnej wagi kolumn

# %%
cols = ['finbert_Score', 'bart_Score', 'vader_Score',
        'mean_future', 'mean_influential', 'mean_trustworthy', 'mean_clickbait',
        'norm_rsi_14', 'norm_rsi_gspc_14',
        'norm_slowk_14', 'norm_roc_14',
        'minmax_BTC-USD_Volume','log_return_7','log_return_1','EURUSD=X_Close',
        'minmax_daily_variation', 'minmax_high_close_pressure',
        'minmax_low_open_pressure',
        'minmax_low_norm', 'minmax_close_norm',
        'minmax_high_norm', 'minmax_open_norm']

u = create_unique_subsets(cols, subset_size=5, min_diff=3)

# %%
shift_ = 5
window_size = 14
target_cols = ['target_7']
y_base_val = val_set[target_cols[0]].shift(shift_)[window_size:].values
y_base_train = train_set[target_cols[0]].shift(shift_)[window_size:].values
y_base0_val = [0 for i in range((val_set.shape[0]-window_size))]
y_base0_train = [0 for i in range((train_set.shape[0]-window_size))]

# %%
len(u)
# Out:
# 97

# %%
df = run_multiple_models(train_set,val_set,u,n_epochs=200)
# Out:
# -------------------------------
# 0
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 1
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 2
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 3
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 4
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 5
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 6
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 7
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 8
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 9
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 10
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 11
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 12
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 13
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 14
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 15
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 16
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 17
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 18
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 19
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 20
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 21
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 22
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 23
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 24
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 25
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 26
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 27
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 28
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 29
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 30
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 31
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 32
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 33
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 34
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 35
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 36
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 37
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 38
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 39
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 40
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 41
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 42
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 43
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 44
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 45
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# -------------------------------
# 46
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-1158ae9ddfb2> in <cell line: 1>()
# ----> 1 df = run_multiple_models(train_set,val_set,u,n_epochs=200)
#
# <ipython-input-66-c786ebaeea74> in run_multiple_models(train_set, val_set, cols_subset, n_epochs)
#      73     X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)
#      74
# ---> 75     model,history = make_model(X,y, X_val, y_val, n_epochs)
#      76
#      77     mse_val.append(min(history.history['val_loss']))
#
# <ipython-input-66-c786ebaeea74> in make_model(X, y, X_val, y_val, n_epochs, lstm_units, dense_units)
#     148
#     149     # Train the model
# --> 150     history = model.fit(X, y, epochs=n_epochs, validation_data=(X_val, y_val),
#     151                         verbose=0)
#     152
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     854
#     855         func = self._select_training_loop(x)
# --> 856         return func.fit(
#     857             self,
#     858             x=x,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_arrays_v1.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     732             val_x, val_y, val_sample_weights = None, None, None
#     733
# --> 734         return fit_loop(
#     735             model,
#     736             inputs=x,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_arrays_v1.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     419
#     420                 # Get outputs.
# --> 421                 batch_outs = f(ins_batch)
#     422                 if not isinstance(batch_outs, list):
#     423                     batch_outs = [batch_outs]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py in __call__(self, inputs)
#    4605             self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
#    4606
# -> 4607         fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4608         self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#    4609         output_structure = tf.nest.pack_sequence_as(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1503       try:
#    1504         run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1505         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1506                                                self._handle, args,
#    1507                                                run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
df.to_csv("df_shap_BTC-USD.csv")

# %%
# df = pd.read_csv("df_shap_final")
# df['cols_used'] = df['cols_used'].apply(parse_cols_used)
# df['aggregated_shap'] = df['aggregated_shap'].apply(parse_shap_values)

top_10_df = df.nsmallest(10, 'mse_val')

# %%
top_10_df
# Out:
#     Unnamed: 0                                          cols_used   mse_val  \
# 44          44  [bart_Score, norm_rsi_14, log_return_5, minmax...  0.000896
# 24          24  [finbert_Score, norm_rsi_14, norm_slowk_14, EU...  0.000970
# 6            6  [finbert_Score, vader_Score, mean_trustworthy,...  0.000979
# 43          43  [bart_Score, norm_rsi_14, norm_rsi_gspc_14, mi...  0.000982
# 35          35  [bart_Score, mean_influential, mean_trustworth...  0.000998
# 37          37  [bart_Score, mean_influential, norm_rsi_14, no...  0.001010
# 4            4  [finbert_Score, bart_Score, EURUSD=X_Close, mi...  0.001012
# 33          33  [bart_Score, mean_future, log_return_1, minmax...  0.001024
# 77          77  [mean_trustworthy, mean_clickbait, minmax_dail...  0.001036
# 45          45  [bart_Score, norm_roc_14, minmax_BA_Volume, mi...  0.001074
#
#     mse_train                                    aggregated_shap
# 44   0.001637  [[0.00184334, 0.001898, 0.00056095, 0.00069737...
# 24   0.001247  [[0.00178253, 0.00254337, 0.00614147, 0.000205...
# 6    0.001118  [[0.00496187, 0.00399872, 0.0038806, 0.0037360...
# 43   0.001148  [[0.00632806, 0.00380524, 0.00244517, 0.003964...
# 35   0.001649  [[0.0031651, 0.00721756, 0.0115292, 0.0020546,...
# 37   0.001106  [[0.00303479, 0.00272496, 0.00744301, 0.008473...
# 4    0.001503  [[0.00151562844, 0.00288658218, 0.000121607885...
# 33   0.001413  [[0.00329247, 0.0015783, 0.00114767, 0.0018132...
# 77   0.001202  [[0.00196569, 0.00251931, 0.00231082, 0.001371...
# 45   0.001856  [[0.0020525, 0.00079285, 0.00286484, 0.0031448...

# %%
column_importance_sum_count = {}

for index, row in top_10_df.iterrows():
    shap_values = row['aggregated_shap']
    cols = row['cols_used']
    mean_shap = np.mean(shap_values, axis=0)

    # Update the sum and count of mean SHAP values for each column
    for col, value in zip(cols, mean_shap):
        if col in column_importance_sum_count:
            column_importance_sum_count[col]['sum'] += value
            column_importance_sum_count[col]['count'] += 1
        else:
            column_importance_sum_count[col] = {'sum': value, 'count': 1}

# Calculate the mean importance for each column
column_importance_mean = {col: (val['sum'] / val['count'] , val['count']) for col, val in column_importance_sum_count.items()}

# Sort the column importance dictionary for better readability
sorted_column_importance_mean = dict(sorted(column_importance_mean.items(), key=lambda item: item[1], reverse=True))

sorted_column_importance_mean
# Out:
# {'mean_influential': (0.0069647545, 2),
#  'vader_Score': (0.006151192, 1),
#  'mean_trustworthy': (0.005497249999999999, 3),
#  'norm_slowk_14': (0.003821961999999999, 2),
#  'minmax_open_norm': (0.0027545899999999995, 2),
#  'bart_Score': (0.0026845468727142857, 7),
#  'minmax_BA_Volume': (0.0023795113333333335, 3),
#  'norm_rsi_gspc_14': (0.0022088505, 2),
#  'finbert_Score': (0.0021158314740000006, 3),
#  'minmax_low_norm': (0.002056984, 3),
#  'minmax_daily_variation': (0.0020565819499999997, 5),
#  'minmax_high_norm': (0.0020123199999999997, 1),
#  'mean_clickbait': (0.002009077, 1),
#  'log_return_1': (0.0017075395000000003, 2),
#  'norm_rsi_14': (0.0017029270000000001, 4),
#  'mean_future': (0.0014067840000000001, 1),
#  'norm_roc_14': (0.0009537300000000001, 1),
#  'minmax_low_open_pressure': (0.0008686176666666667, 3),
#  'log_return_5': (0.0006104670000000001, 1),
#  'EURUSD=X_Close': (0.000109224697125, 2),
#  'minmax_high_close_pressure': (7.05401325e-05, 1)}

# %%
column_importance_sum_count = {}

for index, row in top_10_df.iterrows():
    shap_values = row['aggregated_shap']
    cols = row['cols_used']
    mean_shap = np.max(shap_values, axis=0)

    # Update the sum and count of mean SHAP values for each column
    for col, value in zip(cols, mean_shap):
        if col in column_importance_sum_count:
            column_importance_sum_count[col]['sum'] += value
            column_importance_sum_count[col]['count'] += 1
        else:
            column_importance_sum_count[col] = {'sum': value, 'count': 1}

# Calculate the mean importance for each column
column_importance_mean = {col: (val['sum'] / val['count'] , val['count']) for col, val in column_importance_sum_count.items()}

# Sort the column importance dictionary for better readability
sorted_column_importance_mean = dict(sorted(column_importance_mean.items(), key=lambda item: item[1], reverse=True))

sorted_column_importance_mean
# Out:
# {'mean_influential': (0.01246783, 2),
#  'mean_trustworthy': (0.008722383333333335, 3),
#  'vader_Score': (0.00859614, 1),
#  'norm_slowk_14': (0.007307725, 2),
#  'finbert_Score': (0.004625113366666667, 3),
#  'bart_Score': (0.00398654840342857, 7),
#  'norm_rsi_14': (0.003922405, 4),
#  'minmax_BA_Volume': (0.0037147900000000004, 3),
#  'minmax_open_norm': (0.00363986, 2),
#  'mean_clickbait': (0.00346068, 1),
#  'minmax_daily_variation': (0.0033551848719999998, 5),
#  'norm_rsi_gspc_14': (0.00318714, 2),
#  'minmax_high_norm': (0.00317973, 1),
#  'mean_future': (0.00268053, 1),
#  'log_return_1': (0.00254144, 2),
#  'minmax_low_norm': (0.0025056633333333336, 3),
#  'norm_roc_14': (0.00155015, 1),
#  'minmax_low_open_pressure': (0.0013862266666666665, 3),
#  'log_return_5': (0.00137417, 1),
#  'EURUSD=X_Close': (0.000241295067, 2)}

# %% [markdown]
# ### TOP 10 modeli SHAP

# %%
#max across windows
for index, row in top_10_df.iterrows():
    print(index)
    shap_values = row['aggregated_shap']
    feature_names = row['cols_used']
    plot_mean_feature_importance(shap_values, feature_names,True)
# Out:
# 44
# 24
# 6
# 43
# 35
# 37
# 4
# 33
# 77
# 45

# %%
#mean across windows
for index, row in top_10_df.iterrows():
    print(index)
    shap_values = row['aggregated_shap']
    feature_names = row['cols_used']
    plot_mean_feature_importance(shap_values, feature_names)
# Out:
# 44
# 24
# 6
# 43
# 35
# 37
# 4
# 33
# 77
# 45

# %% [markdown]
# ### Przykładowy model

# %%
window_size = 10
target_cols = ['target_5']
cols_used = {'bart_Score',
 'norm_rsi_14',
 'log_return_5',
 'minmax_low_open_pressure',
 'minmax_open_norm'}
X,y = window_dataset(train_set[list(cols_used)+target_cols],  target_cols[0], window_size)
X_val, y_val = window_dataset(val_set[list(cols_used)+target_cols], target_cols[0], window_size)

#model,history = make_model(X,y,100,lstm_units=32)
model, history = make_model_better(X, y, X_val, y_val, n_epochs=200, lstm_units=32,
                              dense_units=8, patience=100)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Train on 646 samples, validate on 30 samples
# Epoch 1/200
# 646/646 [==============================] - 3s 5ms/sample - loss: 0.0060 - val_loss: 0.0019
# Epoch 2/200
# 646/646 [==============================] - 0s 425us/sample - loss: 0.0031 - val_loss: 0.0017
# Epoch 3/200
# 646/646 [==============================] - 0s 439us/sample - loss: 0.0029 - val_loss: 0.0014
# Epoch 4/200
# 646/646 [==============================] - 0s 427us/sample - loss: 0.0030 - val_loss: 0.0014
# Epoch 5/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0030 - val_loss: 0.0014
# Epoch 6/200
# 646/646 [==============================] - 0s 381us/sample - loss: 0.0029 - val_loss: 0.0015
# Epoch 7/200
# 646/646 [==============================] - 0s 624us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 8/200
# 646/646 [==============================] - 0s 519us/sample - loss: 0.0028 - val_loss: 0.0015
# Epoch 9/200
# 646/646 [==============================] - 0s 518us/sample - loss: 0.0029 - val_loss: 0.0014
# Epoch 10/200
# 646/646 [==============================] - 0s 541us/sample - loss: 0.0029 - val_loss: 0.0015
# Epoch 11/200
# 646/646 [==============================] - 0s 509us/sample - loss: 0.0028 - val_loss: 0.0014
# Epoch 12/200
# 646/646 [==============================] - 0s 567us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 13/200
# 646/646 [==============================] - 0s 536us/sample - loss: 0.0029 - val_loss: 0.0013
# Epoch 14/200
# 646/646 [==============================] - 0s 515us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 15/200
# 646/646 [==============================] - 0s 512us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 16/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0028 - val_loss: 0.0015
# Epoch 17/200
# 646/646 [==============================] - 0s 379us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 18/200
# 646/646 [==============================] - 0s 375us/sample - loss: 0.0029 - val_loss: 0.0014
# Epoch 19/200
# 646/646 [==============================] - 0s 419us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 20/200
# 646/646 [==============================] - 0s 435us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 21/200
# 646/646 [==============================] - 0s 382us/sample - loss: 0.0028 - val_loss: 0.0015
# Epoch 22/200
# 646/646 [==============================] - 0s 419us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 23/200
# 646/646 [==============================] - 0s 383us/sample - loss: 0.0029 - val_loss: 0.0017
# Epoch 24/200
# 646/646 [==============================] - 0s 400us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 25/200
# 646/646 [==============================] - 0s 393us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 26/200
# 646/646 [==============================] - 0s 382us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 27/200
# 646/646 [==============================] - 0s 413us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 28/200
# 646/646 [==============================] - 0s 399us/sample - loss: 0.0029 - val_loss: 0.0014
# Epoch 29/200
# 646/646 [==============================] - 0s 385us/sample - loss: 0.0028 - val_loss: 0.0014
# Epoch 30/200
# 646/646 [==============================] - 0s 380us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 31/200
# 646/646 [==============================] - 0s 379us/sample - loss: 0.0028 - val_loss: 0.0015
# Epoch 32/200
# 646/646 [==============================] - 0s 397us/sample - loss: 0.0028 - val_loss: 0.0013
# Epoch 33/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 34/200
# 646/646 [==============================] - 0s 383us/sample - loss: 0.0027 - val_loss: 0.0014
# Epoch 35/200
# 646/646 [==============================] - 0s 372us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 36/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 37/200
# 646/646 [==============================] - 0s 378us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 38/200
# 646/646 [==============================] - 0s 389us/sample - loss: 0.0027 - val_loss: 0.0015
# Epoch 39/200
# 646/646 [==============================] - 0s 385us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 40/200
# 646/646 [==============================] - 0s 402us/sample - loss: 0.0027 - val_loss: 0.0014
# Epoch 41/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 42/200
# 646/646 [==============================] - 0s 382us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 43/200
# 646/646 [==============================] - 0s 383us/sample - loss: 0.0027 - val_loss: 0.0015
# Epoch 44/200
# 646/646 [==============================] - 0s 397us/sample - loss: 0.0028 - val_loss: 0.0017
# Epoch 45/200
# 646/646 [==============================] - 0s 384us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 46/200
# 646/646 [==============================] - 0s 399us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 47/200
# 646/646 [==============================] - 0s 382us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 48/200
# 646/646 [==============================] - 0s 397us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 49/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0027 - val_loss: 0.0017
# Epoch 50/200
# 646/646 [==============================] - 0s 391us/sample - loss: 0.0029 - val_loss: 0.0016
# Epoch 51/200
# 646/646 [==============================] - 0s 414us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 52/200
# 646/646 [==============================] - 0s 408us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 53/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0027 - val_loss: 0.0014
# Epoch 54/200
# 646/646 [==============================] - 0s 440us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 55/200
# 646/646 [==============================] - 0s 536us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 56/200
# 646/646 [==============================] - 0s 524us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 57/200
# 646/646 [==============================] - 0s 529us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 58/200
# 646/646 [==============================] - 0s 541us/sample - loss: 0.0028 - val_loss: 0.0012
# Epoch 59/200
# 646/646 [==============================] - 0s 535us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 60/200
# 646/646 [==============================] - 0s 616us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 61/200
# 646/646 [==============================] - 0s 551us/sample - loss: 0.0027 - val_loss: 0.0015
# Epoch 62/200
# 646/646 [==============================] - 0s 516us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 63/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 64/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 65/200
# 646/646 [==============================] - 0s 421us/sample - loss: 0.0028 - val_loss: 0.0014
# Epoch 66/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 67/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 68/200
# 646/646 [==============================] - 0s 388us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 69/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 70/200
# 646/646 [==============================] - 0s 376us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 71/200
# 646/646 [==============================] - 0s 414us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 72/200
# 646/646 [==============================] - 0s 389us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 73/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 74/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0027 - val_loss: 0.0017
# Epoch 75/200
# 646/646 [==============================] - 0s 376us/sample - loss: 0.0028 - val_loss: 0.0014
# Epoch 76/200
# 646/646 [==============================] - 0s 383us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 77/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 78/200
# 646/646 [==============================] - 0s 382us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 79/200
# 646/646 [==============================] - 0s 385us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 80/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 81/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 82/200
# 646/646 [==============================] - 0s 391us/sample - loss: 0.0027 - val_loss: 0.0014
# Epoch 83/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 84/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0027 - val_loss: 0.0013
# Epoch 85/200
# 646/646 [==============================] - 0s 427us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 86/200
# 646/646 [==============================] - 0s 385us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 87/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 88/200
# 646/646 [==============================] - 0s 391us/sample - loss: 0.0026 - val_loss: 0.0013
# Epoch 89/200
# 646/646 [==============================] - 0s 396us/sample - loss: 0.0026 - val_loss: 0.0013
# Epoch 90/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0027 - val_loss: 0.0012
# Epoch 91/200
# 646/646 [==============================] - 0s 392us/sample - loss: 0.0026 - val_loss: 0.0014
# Epoch 92/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 93/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0026 - val_loss: 0.0013
# Epoch 94/200
# 646/646 [==============================] - 0s 389us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 95/200
# 646/646 [==============================] - 0s 424us/sample - loss: 0.0026 - val_loss: 0.0014
# Epoch 96/200
# 646/646 [==============================] - 0s 392us/sample - loss: 0.0027 - val_loss: 0.0015
# Epoch 97/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0026 - val_loss: 0.0013
# Epoch 98/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 99/200
# 646/646 [==============================] - 0s 391us/sample - loss: 0.0025 - val_loss: 0.0014
# Epoch 100/200
# 646/646 [==============================] - 0s 415us/sample - loss: 0.0025 - val_loss: 0.0014
# Epoch 101/200
# 646/646 [==============================] - 0s 410us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 102/200
# 646/646 [==============================] - 0s 525us/sample - loss: 0.0025 - val_loss: 0.0014
# Epoch 103/200
# 646/646 [==============================] - 0s 526us/sample - loss: 0.0026 - val_loss: 0.0016
# Epoch 104/200
# 646/646 [==============================] - 0s 537us/sample - loss: 0.0026 - val_loss: 0.0013
# Epoch 105/200
# 646/646 [==============================] - 0s 535us/sample - loss: 0.0025 - val_loss: 0.0015
# Epoch 106/200
# 646/646 [==============================] - 0s 525us/sample - loss: 0.0026 - val_loss: 0.0014
# Epoch 107/200
# 646/646 [==============================] - 0s 521us/sample - loss: 0.0025 - val_loss: 0.0013
# Epoch 108/200
# 646/646 [==============================] - 0s 499us/sample - loss: 0.0025 - val_loss: 0.0012
# Epoch 109/200
# 646/646 [==============================] - 0s 585us/sample - loss: 0.0025 - val_loss: 0.0011
# Epoch 110/200
# 646/646 [==============================] - 0s 533us/sample - loss: 0.0025 - val_loss: 0.0013
# Epoch 111/200
# 646/646 [==============================] - 0s 417us/sample - loss: 0.0024 - val_loss: 0.0013
# Epoch 112/200
# 646/646 [==============================] - 0s 385us/sample - loss: 0.0024 - val_loss: 0.0015
# Epoch 113/200
# 646/646 [==============================] - 0s 384us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 114/200
# 646/646 [==============================] - 0s 401us/sample - loss: 0.0024 - val_loss: 0.0013
# Epoch 115/200
# 646/646 [==============================] - 0s 378us/sample - loss: 0.0024 - val_loss: 0.0013
# Epoch 116/200
# 646/646 [==============================] - 0s 425us/sample - loss: 0.0024 - val_loss: 9.7954e-04
# Epoch 117/200
# 646/646 [==============================] - 0s 384us/sample - loss: 0.0026 - val_loss: 0.0015
# Epoch 118/200
# 646/646 [==============================] - 0s 411us/sample - loss: 0.0026 - val_loss: 0.0012
# Epoch 119/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0024 - val_loss: 0.0013
# Epoch 120/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0024 - val_loss: 0.0011
# Epoch 121/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0023 - val_loss: 0.0014
# Epoch 122/200
# 646/646 [==============================] - 0s 401us/sample - loss: 0.0024 - val_loss: 0.0013
# Epoch 123/200
# 646/646 [==============================] - 0s 393us/sample - loss: 0.0023 - val_loss: 0.0013
# Epoch 124/200
# 646/646 [==============================] - 0s 384us/sample - loss: 0.0024 - val_loss: 0.0012
# Epoch 125/200
# 646/646 [==============================] - 0s 394us/sample - loss: 0.0024 - val_loss: 0.0012
# Epoch 126/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 127/200
# 646/646 [==============================] - 0s 374us/sample - loss: 0.0023 - val_loss: 0.0016
# Epoch 128/200
# 646/646 [==============================] - 0s 374us/sample - loss: 0.0023 - val_loss: 0.0012
# Epoch 129/200
# 646/646 [==============================] - 0s 378us/sample - loss: 0.0023 - val_loss: 0.0012
# Epoch 130/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0023 - val_loss: 0.0012
# Epoch 131/200
# 646/646 [==============================] - 0s 385us/sample - loss: 0.0023 - val_loss: 0.0011
# Epoch 132/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0023 - val_loss: 0.0011
# Epoch 133/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0023 - val_loss: 0.0010
# Epoch 134/200
# 646/646 [==============================] - 0s 405us/sample - loss: 0.0023 - val_loss: 0.0012
# Epoch 135/200
# 646/646 [==============================] - 0s 382us/sample - loss: 0.0024 - val_loss: 0.0013
# Epoch 136/200
# 646/646 [==============================] - 0s 388us/sample - loss: 0.0022 - val_loss: 0.0013
# Epoch 137/200
# 646/646 [==============================] - 0s 392us/sample - loss: 0.0023 - val_loss: 0.0012
# Epoch 138/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 139/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0023 - val_loss: 0.0013
# Epoch 140/200
# 646/646 [==============================] - 0s 389us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 141/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0022 - val_loss: 0.0011
# Epoch 142/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0022 - val_loss: 0.0011
# Epoch 143/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 144/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 145/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0022 - val_loss: 0.0013
# Epoch 146/200
# 646/646 [==============================] - 0s 430us/sample - loss: 0.0022 - val_loss: 0.0011
# Epoch 147/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0021 - val_loss: 0.0013
# Epoch 148/200
# 646/646 [==============================] - 0s 393us/sample - loss: 0.0023 - val_loss: 0.0012
# Epoch 149/200
# 646/646 [==============================] - 0s 404us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 150/200
# 646/646 [==============================] - 0s 498us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 151/200
# 646/646 [==============================] - 0s 617us/sample - loss: 0.0021 - val_loss: 0.0013
# Epoch 152/200
# 646/646 [==============================] - 0s 684us/sample - loss: 0.0022 - val_loss: 0.0011
# Epoch 153/200
# 646/646 [==============================] - 0s 605us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 154/200
# 646/646 [==============================] - 0s 521us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 155/200
# 646/646 [==============================] - 0s 524us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 156/200
# 646/646 [==============================] - 0s 518us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 157/200
# 646/646 [==============================] - 0s 504us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 158/200
# 646/646 [==============================] - 0s 530us/sample - loss: 0.0022 - val_loss: 0.0018
# Epoch 159/200
# 646/646 [==============================] - 0s 529us/sample - loss: 0.0022 - val_loss: 0.0012
# Epoch 160/200
# 646/646 [==============================] - 0s 447us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 161/200
# 646/646 [==============================] - 0s 401us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 162/200
# 646/646 [==============================] - 0s 400us/sample - loss: 0.0020 - val_loss: 0.0011
# Epoch 163/200
# 646/646 [==============================] - 0s 391us/sample - loss: 0.0021 - val_loss: 0.0012
# Epoch 164/200
# 646/646 [==============================] - 0s 380us/sample - loss: 0.0022 - val_loss: 0.0014
# Epoch 165/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0021 - val_loss: 0.0014
# Epoch 166/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0019 - val_loss: 0.0012
# Epoch 167/200
# 646/646 [==============================] - 0s 393us/sample - loss: 0.0021 - val_loss: 0.0014
# Epoch 168/200
# 646/646 [==============================] - 0s 392us/sample - loss: 0.0020 - val_loss: 0.0012
# Epoch 169/200
# 646/646 [==============================] - 0s 393us/sample - loss: 0.0022 - val_loss: 0.0014
# Epoch 170/200
# 646/646 [==============================] - 0s 402us/sample - loss: 0.0021 - val_loss: 0.0010
# Epoch 171/200
# 646/646 [==============================] - 0s 389us/sample - loss: 0.0020 - val_loss: 0.0013
# Epoch 172/200
# 646/646 [==============================] - 0s 388us/sample - loss: 0.0020 - val_loss: 0.0013
# Epoch 173/200
# 646/646 [==============================] - 0s 386us/sample - loss: 0.0020 - val_loss: 0.0012
# Epoch 174/200
# 646/646 [==============================] - 0s 399us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 175/200
# 646/646 [==============================] - 0s 384us/sample - loss: 0.0020 - val_loss: 0.0014
# Epoch 176/200
# 646/646 [==============================] - 0s 391us/sample - loss: 0.0020 - val_loss: 0.0012
# Epoch 177/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 178/200
# 646/646 [==============================] - 0s 420us/sample - loss: 0.0019 - val_loss: 0.0014
# Epoch 179/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0020 - val_loss: 0.0013
# Epoch 180/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0020 - val_loss: 0.0013
# Epoch 181/200
# 646/646 [==============================] - 0s 392us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 182/200
# 646/646 [==============================] - 0s 398us/sample - loss: 0.0019 - val_loss: 0.0014
# Epoch 183/200
# 646/646 [==============================] - 0s 412us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 184/200
# 646/646 [==============================] - 0s 394us/sample - loss: 0.0020 - val_loss: 0.0011
# Epoch 185/200
# 646/646 [==============================] - 0s 387us/sample - loss: 0.0019 - val_loss: 0.0012
# Epoch 186/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0019 - val_loss: 0.0014
# Epoch 187/200
# 646/646 [==============================] - 0s 389us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 188/200
# 646/646 [==============================] - 0s 392us/sample - loss: 0.0019 - val_loss: 0.0010
# Epoch 189/200
# 646/646 [==============================] - 0s 393us/sample - loss: 0.0020 - val_loss: 0.0011
# Epoch 190/200
# 646/646 [==============================] - 0s 417us/sample - loss: 0.0019 - val_loss: 0.0011
# Epoch 191/200
# 646/646 [==============================] - 0s 395us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 192/200
# 646/646 [==============================] - 0s 418us/sample - loss: 0.0019 - val_loss: 0.0011
# Epoch 193/200
# 646/646 [==============================] - 0s 396us/sample - loss: 0.0019 - val_loss: 0.0012
# Epoch 194/200
# 646/646 [==============================] - 0s 407us/sample - loss: 0.0018 - val_loss: 0.0017
# Epoch 195/200
# 646/646 [==============================] - 0s 461us/sample - loss: 0.0021 - val_loss: 9.5671e-04
# Epoch 196/200
# 646/646 [==============================] - 0s 414us/sample - loss: 0.0019 - val_loss: 0.0011
# Epoch 197/200
# 646/646 [==============================] - 0s 390us/sample - loss: 0.0018 - val_loss: 0.0012
# Epoch 198/200
# 646/646 [==============================] - 0s 403us/sample - loss: 0.0019 - val_loss: 0.0013
# Epoch 199/200
# 646/646 [==============================] - 0s 527us/sample - loss: 0.0017 - val_loss: 0.0013
# Epoch 200/200
# 646/646 [==============================] - 0s 515us/sample - loss: 0.0018 - val_loss: 0.0013

# %% [markdown]
# #### wyniki

# %%
model = load_model('best_model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
y_pred_val = model.predict(X_val)
y_pred_train = model.predict(X)

# %%
k=-60
plot_actual_vs_predicted(y[k:], y_pred_train[k:], y_base0_train[k:])

# %%
plot_actual_vs_predicted(y_val, y_pred_val, y_base0_val)

# %%
print('Model')
print(calculate_metrics(y, y_pred_train, np.array([1]), np.array([1]), y_val, y_pred_val))
print('-----')
print('Baseline 0')
print(calculate_metrics(y, y_base0_train, np.array([1]), np.array([1]), y_val, y_base0_val))
print('-----')
print('Baseline Prev')
print(calculate_metrics(y, y_base_train, np.array([1]), np.array([1]), y_val, y_base_val))
# Out:
# Model
#                  MAE       MSE      RMSE  R2 Score         MAPE      MASE
# Train       0.033652  0.001944  0.044089  0.318572   295.632777  1.291433
# Test        0.000000  0.000000  0.000000       NaN     0.000000  0.000000
# Validation  0.024451  0.000957  0.030931  0.313142  1584.531329  0.938321
# -----
# Baseline 0
#                  MAE       MSE      RMSE  R2 Score   MAPE      MASE
# Train       0.039650  0.002853  0.053411 -0.000031  100.0  1.521588
# Test        0.000000  0.000000  0.000000       NaN    0.0  0.000000
# Validation  0.027415  0.001435  0.037876 -0.029927  100.0  1.052056
# -----
# Baseline Prev
#                  MAE       MSE      RMSE  R2 Score         MAPE      MASE
# Train       0.058321  0.005983  0.077351 -1.097411   552.156845  2.238101
# Test        0.000000  0.000000  0.000000       NaN     0.000000  0.000000
# Validation  0.052187  0.004144  0.064371 -1.974836  4423.503320  2.002708

# %%
explainer = shap.DeepExplainer(model, X)
shap_values = explainer.shap_values(X_val)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_feature_importance(shap_values, feature_names,window_size):
    """
    Plot the importance of each feature at each step in the window.

    :param shap_values: A 3D array of SHAP values with shape (samples, window_size, num_features).
    :param feature_names: List of feature names.
    """
    # Aggregate SHAP values across all samples
    aggregated_shap = np.mean(np.abs(shap_values[0]), axis=0)

    # Create a plot for each time step in the window
    window_size = aggregated_shap.shape[0]
    num_features = aggregated_shap.shape[1]

    # Set up the plot
    fig, axs = plt.subplots(window_size, 1, figsize=(10, window_size * 2))
    fig.suptitle('Feature Importance in Each Window Step')

    # Plot each time step
    for i in range(window_size):
        axs[i].bar(feature_names, aggregated_shap[i, :])
        axs[i].set_title(f'Time Step {i+1}')
        axs[i].set_ylabel('SHAP Value')
        axs[i].set_xlabel('Features')

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# Example usage
feature_names = list(cols_used)
plot_feature_importance(shap_values, feature_names,window_size)
